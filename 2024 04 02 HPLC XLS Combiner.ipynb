# %%
# v2.5
# Moved the percent area column next to left of the retime
import os
import xlrd
import pandas as pd
import re

def extract_data_from_file(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')

    # Extract data from Signal sheet
    signal_sheet = wb.sheet_by_name('Signal')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):
        # Extract Method from Sheet1 cell B6
        method = sheet1.cell_value(rowx=5, colx=1)  # B6
        
        # Extract Sequence from Sheet1 cell B5
        sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
        sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right

        # Extract File Name from Signal Sheet H2
        file_name_text = signal_sheet.cell_value(rowx=1, colx=7)  # H2
        file_name = file_name_text.rsplit("\\", 2)[-1]
        
        # Initialize dictionary for current row data
        row_data = {}

        # Add a column named 'SeqLine' with value equal to the seqline
        row_data['SeqLine'] = sheet1.cell_value(rowx=18, colx=1)  # B19
        
        # Add a column named 'Sample' with value equal to the sample name
        row_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
        
        # Add a column named 'Peak' with value equal to the current loop number n
        row_data['Peak'] = row

        # Add other data columns recursively
        for col, label in zip(range(4, 9), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)
        
        # Add Sequence, Method, and File Name to row data
        row_data['Sequence'] = sequence
        row_data['File Name'] = file_name
        row_data['Method'] = method

        # Append the row data to the list
        rows_data.append(row_data)

    if not rows_data:
        print(f"No data extracted from {file_path}")
    
    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)
    
    # Debug print to check DataFrame columns
    print(f"Columns in DataFrame for file {file_path}: {int_results_df.columns}")

    # Convert SeqLine to string for mixed digit numbers
    if 'SeqLine' in int_results_df.columns:
        int_results_df['SeqLine'] = int_results_df['SeqLine'].astype(str)
    else:
        print(f"'SeqLine' column not found in the data extracted from {file_path}")
    
    return int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []
    skipped_xls_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Check that the .xls file is an HPLC report with an int result sheet
                try:
                    # Open the Excel file
                    wb = xlrd.open_workbook(file_path)
                    wb.sheet_by_name('IntResults1')
                
                # If error, skip this file and add it to the skipped list
                except xlrd.XLRDError:
                    skipped_xls_list.append(file_path)
                    print(file_path)
                    continue
                
                # Extract data from specific cells
                int_results_df = extract_data_from_file(file_path)
                
                # Append the extracted data to the respective lists
                int_results_df_list.append(int_results_df)

    if not int_results_df_list:
        print("No '.xls' files with 'IntResults1' sheet found.")
        return

    # Concatenate all DataFrames into a single DataFrame
    int_results_df_combined = pd.concat(int_results_df_list, ignore_index=True)
    
    # Define the sorting order
    sorting_order = ['Sequence', 'SeqLine']
    
    # Convert 'SeqLine' to integer type for sorting
    int_results_df_combined['SeqLine'] = int_results_df_combined['SeqLine'].astype(str)
    int_results_df_combined['SeqLine'] = int_results_df_combined['SeqLine'].apply(extract_numeric_part)
    
    # Sort the combined DataFrame by the specified order
    int_results_df_combined.sort_values(by=sorting_order, ascending=[False, True], inplace=True)
    
    # Calculate total area for each SeqLine
    total_area_by_seqline = int_results_df_combined.groupby('SeqLine')['Area'].sum()
    
    # Calculate area percent for each peak
    int_results_df_combined['Area_Percent'] = int_results_df_combined.apply(
        lambda row: (row['Area'] / total_area_by_seqline[row['SeqLine']]) * 100, axis=1
    )
    
    # Reorder columns to move 'Area_Percent' to the left of 'RetTime'
    cols = ['Sequence', 'SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'File Name', 'Method']
    int_results_df_combined = int_results_df_combined[cols]
    
    # Print the extracted DataFrame
    print("\nIntResults DataFrame:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    file_name = "HPLC_Summary_" + parent_directory.rsplit("\\", 2)[-1] + ".csv"
    try:
        if int_results_df_combined['Sequence'].iloc[0] == int_results_df_combined['Sequence'].iloc[-1]:
            int_results_csv_path = os.path.join(parent_directory, file_name)
            int_results_df_combined.to_csv(int_results_csv_path, index=False)
    except:
        int_results_csv_path = os.path.join(parent_directory, "HPLC_Summary.csv")
        int_results_df_combined.to_csv(int_results_csv_path, index=False)
    
    # Print skipped file list
    print("Skipped files:", skipped_xls_list)
    
    # Print location of output file
    print(f"Results saved to: {int_results_csv_path}")
    
    # Input pause so user can see result path
    input("Press the <ENTER> key to continue...")

        
# Define a function to extract the numeric part from the SeqLine string
def extract_numeric_part(seqline):
    # Use regular expression to find the numeric part
    match = re.search(r'\d+', seqline)
    if match:
        return int(match.group())  # Return the numeric part as integer
    else:
        return 0  # If no numeric part found, return 0

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path: C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44
# WARNING *** file size (31937) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31937) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\003-0101.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (33623) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33623) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\003-0201.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (31937) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31937) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\003-0301.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (34826) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34826) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AA-0401.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (35669) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35669) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AB-0501.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (35309) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35309) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AC-0601.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (31937) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31937) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AE-0701.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (35309) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35309) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AF-0801.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (33623) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33623) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AH-0901.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (34466) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34466) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AI-1001.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AJ-1101.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (33625) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33625) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AK-1201.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (33625) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33625) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AL-1301.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (33625) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33625) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BA-1401.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BB-1501.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BD-1601.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (31939) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31939) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BE-1701.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BF-1801.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BG-1901.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (33625) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33625) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BH-2001.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (34468) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34468) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BI-2101.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (34468) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34468) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BJ-2201.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BK-2301.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (35311) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35311) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BL-2401.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (35311) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35311) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1CA-2501.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (35311) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35311) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1CB-2601.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
#
# IntResults DataFrame:
#                                              Sequence  SeqLine Sample  Peak  \
# 0   2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...        1    pbs     1
# 1   2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...        2    pbs     1
# 2   2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...        2    pbs     2
# 3   2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...        2    pbs     3
# 4   2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...        3    pbs     1
# ..                                                ...      ...    ...   ...
# 73  2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...       26  SEQ26     1
# 74  2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...       26  SEQ26     2
# 75  2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...       26  SEQ26     3
# 76  2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...       26  SEQ26     4
# 77  2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...       26  SEQ26     5
#
#     Area_Percent   RetTime        Area     Height     Width  Symmetry  \
# 0     100.000000  5.232315   21.434975   1.565517  0.189739  0.508231
# 1       6.890183  3.943441   15.767656   1.342448  0.149030  5.990731
# 2      73.900826  5.212444  169.116394   2.938217  0.685504  9.820485
# 3      19.208991  5.674413   43.958309   4.357230  0.161700  1.368157
# 4     100.000000  5.210262   22.608757   1.804892  0.180141  0.375654
# ..           ...       ...         ...        ...       ...       ...
# 73     20.609188  0.932763  197.391129  13.593854  0.221407  0.834670
# 74      3.192331  3.360204   30.575575   2.382190  0.193742  0.679479
# 75     73.661270  3.871080  705.514526  47.006943  0.233102  0.599383
# 76      0.817219  6.358583    7.827177   1.054057  0.108634  0.917946
# 77      1.719992  6.535833   16.473780   1.783036  0.137790  0.791992
#
#      File Name            Method
# 0   003-0101.D  LHN SEC2 150MM.M
# 1   003-0201.D  LHN SEC2 150MM.M
# 2   003-0201.D  LHN SEC2 150MM.M
# 3   003-0201.D  LHN SEC2 150MM.M
# 4   003-0301.D  LHN SEC2 150MM.M
# ..         ...               ...
# 73  1CB-2601.D  LHN SEC2 150MM.M
# 74  1CB-2601.D  LHN SEC2 150MM.M
# 75  1CB-2601.D  LHN SEC2 150MM.M
# 76  1CB-2601.D  LHN SEC2 150MM.M
# 77  1CB-2601.D  LHN SEC2 150MM.M
#
# [78 rows x 12 columns]
# Skipped files: []
# Results saved to: C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\HPLC_Summary_2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44.csv

# %%
#v 2.4
# Manually calculates the area percent by adding the areas and dividing the area by the sum.

import os
import xlrd
import pandas as pd
import re

def extract_data_from_file(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')

    # Extract data from Signal sheet
    signal_sheet = wb.sheet_by_name('Signal')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):
        # Extract Method from Sheet1 cell B6
        method = sheet1.cell_value(rowx=5, colx=1)  # B6
        
        # Extract Sequence from Sheet1 cell B5
        sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
        sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right

        # Extract File Name from Signal Sheet H2
        file_name_text = signal_sheet.cell_value(rowx=1, colx=7)  # H2
        file_name = file_name_text.rsplit("\\", 2)[-1]
        
        # Initialize dictionary for current row data
        row_data = {}

        # Add a column named 'SeqLine' with value equal to the seqline
        row_data['SeqLine'] = sheet1.cell_value(rowx=18, colx=1)  # B19
        
        # Add a column named 'Sample' with value equal to the sample name
        row_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
        
        # Add a column named 'Peak' with value equal to the current loop number n
        row_data['Peak'] = row

        # Add other data columns recursively
        for col, label in zip(range(4, 9), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)
        
        # Add Sequence, Method, and File Name to row data
        row_data['Sequence'] = sequence
        row_data['File Name'] = file_name
        row_data['Method'] = method

        # Append the row data to the list
        rows_data.append(row_data)

    if not rows_data:
        print(f"No data extracted from {file_path}")
    
    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)
    
    # Debug print to check DataFrame columns
    print(f"Columns in DataFrame for file {file_path}: {int_results_df.columns}")

    # Convert SeqLine to string for mixed digit numbers
    if 'SeqLine' in int_results_df.columns:
        int_results_df['SeqLine'] = int_results_df['SeqLine'].astype(str)
    else:
        print(f"'SeqLine' column not found in the data extracted from {file_path}")
    
    return int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []
    skipped_xls_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Check that the .xls file is an HPLC report with an int result sheet
                try:
                    # Open the Excel file
                    wb = xlrd.open_workbook(file_path)
                    wb.sheet_by_name('IntResults1')
                
                # If error, skip this file and add it to the skipped list
                except xlrd.XLRDError:
                    skipped_xls_list.append(file_path)
                    print(file_path)
                    continue
                
                # Extract data from specific cells
                int_results_df = extract_data_from_file(file_path)
                
                # Append the extracted data to the respective lists
                int_results_df_list.append(int_results_df)

    if not int_results_df_list:
        print("No '.xls' files with 'IntResults1' sheet found.")
        return

    # Concatenate all DataFrames into a single DataFrame
    int_results_df_combined = pd.concat(int_results_df_list, ignore_index=True)
    
    # Define the sorting order
    sorting_order = ['Sequence', 'SeqLine']
    
    # Convert 'SeqLine' to integer type for sorting
    int_results_df_combined['SeqLine'] = int_results_df_combined['SeqLine'].astype(str)
    int_results_df_combined['SeqLine'] = int_results_df_combined['SeqLine'].apply(extract_numeric_part)
    
    # Sort the combined DataFrame by the specified order
    int_results_df_combined.sort_values(by=sorting_order, ascending=[False, True], inplace=True)
    
    # Calculate total area for each SeqLine
    total_area_by_seqline = int_results_df_combined.groupby('SeqLine')['Area'].sum()
    
    # Calculate area percent for each peak
    int_results_df_combined['Area_Percent'] = int_results_df_combined.apply(
        lambda row: (row['Area'] / total_area_by_seqline[row['SeqLine']]) * 100, axis=1
    )
    
    # Print the extracted DataFrame
    print("\nIntResults DataFrame:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    file_name = "HPLC_Summary_" + parent_directory.rsplit("\\", 2)[-1] + ".csv"
    try:
        if int_results_df_combined['Sequence'].iloc[0] == int_results_df_combined['Sequence'].iloc[-1]:
            int_results_csv_path = os.path.join(parent_directory, file_name)
            int_results_df_combined.to_csv(int_results_csv_path, index=False)
    except:
        int_results_csv_path = os.path.join(parent_directory, "HPLC_Summary.csv")
        int_results_df_combined.to_csv(int_results_csv_path, index=False)
    
    # Print skipped file list
    print("Skipped files:", skipped_xls_list)
    
    # Print location of output file
    print(f"Results saved to: {int_results_csv_path}")
    
    # Input pause so user can see result path
    input("Press the <ENTER> key to continue...")

        
# Define a function to extract the numeric part from the SeqLine string
def extract_numeric_part(seqline):
    # Use regular expression to find the numeric part
    match = re.search(r'\d+', seqline)
    if match:
        return int(match.group())  # Return the numeric part as integer
    else:
        return 0  # If no numeric part found, return 0

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path: C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44
# WARNING *** file size (31937) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31937) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\003-0101.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (33623) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33623) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\003-0201.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (31937) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31937) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\003-0301.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (34826) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34826) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AA-0401.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (35669) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35669) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AB-0501.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (35309) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35309) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AC-0601.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (31937) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31937) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AE-0701.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (35309) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35309) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AF-0801.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (33623) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33623) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AH-0901.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (34466) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34466) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AI-1001.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AJ-1101.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (33625) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33625) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AK-1201.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (33625) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33625) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1AL-1301.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (33625) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33625) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BA-1401.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BB-1501.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BD-1601.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (31939) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31939) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BE-1701.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BF-1801.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BG-1901.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (33625) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33625) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BH-2001.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (34468) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34468) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BI-2101.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (34468) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34468) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BJ-2201.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32782) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BK-2301.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (35311) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35311) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1BL-2401.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (35311) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35311) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1CA-2501.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (35311) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35311) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\1CB-2601.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'RetTime', 'Area', 'Height', 'Width',
#        'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
#
# IntResults DataFrame:
#     SeqLine Sample  Peak   RetTime        Area     Height     Width  Symmetry  \
# 0         1    pbs     1  5.232315   21.434975   1.565517  0.189739  0.508231
# 1         2    pbs     1  3.943441   15.767656   1.342448  0.149030  5.990731
# 2         2    pbs     2  5.212444  169.116394   2.938217  0.685504  9.820485
# 3         2    pbs     3  5.674413   43.958309   4.357230  0.161700  1.368157
# 4         3    pbs     1  5.210262   22.608757   1.804892  0.180141  0.375654
# ..      ...    ...   ...       ...         ...        ...       ...       ...
# 73       26  SEQ26     1  0.932763  197.391129  13.593854  0.221407  0.834670
# 74       26  SEQ26     2  3.360204   30.575575   2.382190  0.193742  0.679479
# 75       26  SEQ26     3  3.871080  705.514526  47.006943  0.233102  0.599383
# 76       26  SEQ26     4  6.358583    7.827177   1.054057  0.108634  0.917946
# 77       26  SEQ26     5  6.535833   16.473780   1.783036  0.137790  0.791992
#
#                                              Sequence   File Name  \
# 0   2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...  003-0101.D
# 1   2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...  003-0201.D
# 2   2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...  003-0201.D
# 3   2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...  003-0201.D
# 4   2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...  003-0301.D
# ..                                                ...         ...
# 73  2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...  1CB-2601.D
# 74  2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...  1CB-2601.D
# 75  2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...  1CB-2601.D
# 76  2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...  1CB-2601.D
# 77  2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-2...  1CB-2601.D
#
#               Method  Area_Percent
# 0   LHN SEC2 150MM.M    100.000000
# 1   LHN SEC2 150MM.M      6.890183
# 2   LHN SEC2 150MM.M     73.900826
# 3   LHN SEC2 150MM.M     19.208991
# 4   LHN SEC2 150MM.M    100.000000
# ..               ...           ...
# 73  LHN SEC2 150MM.M     20.609188
# 74  LHN SEC2 150MM.M      3.192331
# 75  LHN SEC2 150MM.M     73.661270
# 76  LHN SEC2 150MM.M      0.817219
# 77  LHN SEC2 150MM.M      1.719992
#
# [78 rows x 12 columns]
# Skipped files: []
# Results saved to: C:\Users\JoelTencer\Documents\HPLC-1\SEC\2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44\HPLC_Summary_2024 07 21 ATTO-005 HEAT STRESS TEST 2024-07-21 13-17-44.csv
# Press the <ENTER> key to continue...

# %%
# v2.3
# fixed seqline error with chatgpt
# Added a check to see if rows_data is empty after the data extraction loop.
# Added debug prints to check the columns in the DataFrame after creating it.
# Added a check to ensure 'SeqLine' exists in the DataFrame before attempting to convert it to a string type.

import os
import xlrd
import pandas as pd
import re

def extract_data_from_file(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')

    # Extract data from Signal sheet
    signal_sheet = wb.sheet_by_name('Signal')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):
        # Extract Method from Sheet1 cell B6
        method = sheet1.cell_value(rowx=5, colx=1)  # B6
        
        # Extract Sequence from Sheet1 cell B5
        sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
        sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right

        # Extract File Name from Signal Sheet H2
        file_name_text = signal_sheet.cell_value(rowx=1, colx=7)  # H2
        file_name = file_name_text.rsplit("\\", 2)[-1]
        
        # Initialize dictionary for current row data
        row_data = {}

        # Add a column named 'SeqLine' with value equal to the seqline
        row_data['SeqLine'] = sheet1.cell_value(rowx=18, colx=1)  # B19
        
        # Add a column named 'Sample' with value equal to the sample name
        row_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
        
        # Add a column named 'Peak' with value equal to the current loop number n
        row_data['Peak'] = row

        # Check if column 22 has a value, set area percent accordingly
        try:
            area_percent = int_results_sheet.cell_value(rowx=row, colx=22)
        except IndexError:
            area_percent = ""
        row_data['Area_Percent'] = area_percent
        
        # Add other data columns recursively
        for col, label in zip(range(4, 9), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)

        
        # Add Sequence, Method, and File Name to row data
        row_data['Sequence'] = sequence
        row_data['File Name'] = file_name
        row_data['Method'] = method

        # Append the row data to the list
        rows_data.append(row_data)

    if not rows_data:
        print(f"No data extracted from {file_path}")
    
    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)
    
    # Debug print to check DataFrame columns
    print(f"Columns in DataFrame for file {file_path}: {int_results_df.columns}")

    # Convert SeqLine to string for mixed digit numbers
    if 'SeqLine' in int_results_df.columns:
        int_results_df['SeqLine'] = int_results_df['SeqLine'].astype(str)
    else:
        print(f"'SeqLine' column not found in the data extracted from {file_path}")
    
    return int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []
    skipped_xls_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Check that the .xls file is an HPLC report with an int result sheet
                try:
                    # Open the Excel file
                    wb = xlrd.open_workbook(file_path)
                    wb.sheet_by_name('IntResults1')
                
                # If error, skip this file and add it to the skipped list
                except xlrd.XLRDError:
                    skipped_xls_list.append(file_path)
                    print(file_path)
                    continue
                
                # Extract data from specific cells
                int_results_df = extract_data_from_file(file_path)
                
                # Append the extracted data to the respective lists
                int_results_df_list.append(int_results_df)

    if not int_results_df_list:
        print("No '.xls' files with 'IntResults1' sheet found.")
        return

    # Concatenate all DataFrames into a single DataFrame
    int_results_df_combined = pd.concat(int_results_df_list, ignore_index=True)
    
    # Define the sorting order
    sorting_order = ['Sequence', 'SeqLine']
    
    # Convert 'SeqLine' to integer type for sorting
    int_results_df_combined['SeqLine'] = int_results_df_combined['SeqLine'].astype(str)
    int_results_df_combined['SeqLine'] = int_results_df_combined['SeqLine'].apply(extract_numeric_part)
    
    # Sort the combined DataFrame by the specified order
    int_results_df_combined.sort_values(by=sorting_order, ascending=[False, True], inplace=True)
    
    # Print the extracted DataFrame
    # print("\nIntResults DataFrame:")
    # print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    file_name = "HPLC_Summary_" + parent_directory.rsplit("\\", 2)[-1] + ".csv"
    try:
        if int_results_df_combined['Sequence'].iloc[0] == int_results_df_combined['Sequence'].iloc[-1]:
            int_results_csv_path = os.path.join(parent_directory, file_name)
            int_results_df_combined.to_csv(int_results_csv_path, index=False)
    except:
        int_results_csv_path = os.path.join(parent_directory, "HPLC_Summary.csv")
        int_results_df_combined.to_csv(int_results_csv_path, index=False)
    
    # Print skipped file list
    print("Skipped files:", skipped_xls_list)
    
    # Print location of output file
    print(f"Results saved to: {int_results_csv_path}")
    
    # Input pause so user can see result path
    input("Press the <ENTER> key to continue...")

        
# Define a function to extract the numeric part from the SeqLine string
def extract_numeric_part(seqline):
    # Use regular expression to find the numeric part
    match = re.search(r'\d+', seqline)
    if match:
        return int(match.group())  # Return the numeric part as integer
    else:
        return 0  # If no numeric part found, return 0

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10
# WARNING *** file size (43135) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (43135) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\003-0101.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (38810) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38810) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\003-0201.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (34979) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34979) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\003-0301.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (34979) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34979) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\003-2601.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (34983) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34983) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\003-4001.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (39052) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39052) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1AA-1101.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (40596) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (40596) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1AB-1801.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (37985) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37985) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1AC-2401.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (39052) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39052) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1AE-3301.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (35652) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35652) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1AG-4601.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (37346) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37346) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1AH-5401.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (39509) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39509) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1AI-1001.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (39020) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39020) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1BA-1201.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (37172) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37172) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1BB-1901.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (38828) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38828) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1BC-2501.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (35688) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35688) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1BE-3401.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (37530) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37530) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1BF-3801.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (38179) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38179) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1BG-4701.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (38189) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38189) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1BH-5501.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (37362) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37362) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1BI-6201.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (38828) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38828) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1CA-1301.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (36539) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (36539) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1CB-0401.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (39020) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39020) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1CC-2701.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (33521) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33521) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# No data extracted from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1CD-2801.D\REPORT01.xls
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1CD-2801.D\REPORT01.xls: RangeIndex(start=0, stop=0, step=1)
# 'SeqLine' column not found in the data extracted from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1CD-2801.D\REPORT01.xls
# WARNING *** file size (38035) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38035) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1CE-0601.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (38181) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38181) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1CF-3901.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (39503) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39503) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1CG-4801.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (37993) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37993) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1CH-5601.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (39020) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39020) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1DA-1401.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (36533) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (36533) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1DB-2001.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (33521) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33521) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# No data extracted from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1DD-2901.D\REPORT01.xls
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1DD-2901.D\REPORT01.xls: RangeIndex(start=0, stop=0, step=1)
# 'SeqLine' column not found in the data extracted from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1DD-2901.D\REPORT01.xls
# WARNING *** file size (38037) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38037) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1DE-0701.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (38181) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38181) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1DF-4101.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (38371) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38371) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1DG-4901.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (35656) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35656) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1DH-5701.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (39018) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39018) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1EA-1501.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (35690) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35690) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1EB-2101.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (33521) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33521) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# No data extracted from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1ED-3001.D\REPORT01.xls
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1ED-3001.D\REPORT01.xls: RangeIndex(start=0, stop=0, step=1)
# 'SeqLine' column not found in the data extracted from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1ED-3001.D\REPORT01.xls
# WARNING *** file size (38870) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38870) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1EE-3501.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (39024) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39024) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1EF-4201.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (39705) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39705) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1EG-5001.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (37150) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37150) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1EH-5801.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (39022) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39022) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1FA-1601.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (38219) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38219) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1FB-2201.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (33509) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33509) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# No data extracted from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1FD-3101.D\REPORT01.xls
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1FD-3101.D\REPORT01.xls: RangeIndex(start=0, stop=0, step=1)
# 'SeqLine' column not found in the data extracted from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1FD-3101.D\REPORT01.xls
# WARNING *** file size (37983) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37983) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1FE-3601.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (35886) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35886) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1FF-4301.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (36501) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (36501) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1FG-5101.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (37993) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37993) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1FH-5901.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (39020) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39020) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1GA-1701.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (39701) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39701) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1GB-0801.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (33513) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33513) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# No data extracted from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1GD-3201.D\REPORT01.xls
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1GD-3201.D\REPORT01.xls: RangeIndex(start=0, stop=0, step=1)
# 'SeqLine' column not found in the data extracted from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1GD-3201.D\REPORT01.xls
# WARNING *** file size (38836) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38836) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1GE-0901.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (38179) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38179) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1GF-4401.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (37346) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37346) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1GG-5201.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (37993) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37993) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1GH-6001.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (35648) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35648) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1HB-2301.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (35694) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35694) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1HD-0501.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (38826) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38826) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1HE-3701.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (36493) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (36493) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1HF-4501.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (39705) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39705) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1HG-5301.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# WARNING *** file size (39028) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39028) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Columns in DataFrame for file \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1HH-6101.D\REPORT01.xls: Index(['SeqLine', 'Sample', 'Peak', 'Area_Percent', 'RetTime', 'Area',
#        'Height', 'Width', 'Symmetry', 'Sequence', 'File Name', 'Method'],
#       dtype='object')
# Skipped files: []
# Results saved to: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\HPLC_Summary_2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10.csv

# %%
# v2.2
# Added check to main loop to skip if the xls file does not contain the intresult sheet
# Added report at end which files were skipped for not containing this
# Add DAD signal for each?
# Must use short or detail report, full does not have area percent
# Test with other column run data

import os
import xlrd
import pandas as pd
import re

def extract_data_from_file(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')

    # Extract data from Signal sheet
    signal_sheet = wb.sheet_by_name('Signal')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):
        # Extract Method from Sheet1 cell B6
        method = sheet1.cell_value(rowx=5, colx=1)  # B6
        
        # Extract Sequence from Sheet1 cell B5
        sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
        sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right

        # Extract File Name from Signal Sheet H2
        file_name_text = signal_sheet.cell_value(rowx=1, colx=7)  # H2
        file_name = file_name_text.rsplit("\\", 2)[-1]
        
        # Initialize dictionary for current row data
        row_data = {}

        # Add a column named 'SeqLine' with value equal to the sample name
        row_data['SeqLine'] = sheet1.cell_value(rowx=18, colx=1)  # B19
        
        # Add a column named 'Sample' with value equal to the sample name
        row_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
        
        # Add a column named 'Peak' with value equal to the current loop number n
        row_data['Peak'] = row

        # Check if column 22 has a value, set area percent accordingly
        try:
            area_percent = int_results_sheet.cell_value(rowx=row, colx=22)
        except IndexError:
            area_percent = ""
        row_data['Area_Percent'] = area_percent
        
        # Add other data columns recursively
        for col, label in zip(range(4, 9), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)

        
        # Add Sequence, Method, and File Name to row data
        row_data['Sequence'] = sequence
        row_data['File Name'] = file_name
        row_data['Method'] = method

        # Append the row data to the list
        rows_data.append(row_data)

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    # Convert SeqLine to string for mixed digit numbers
    int_results_df['SeqLine'] = int_results_df['SeqLine'].astype(str)

    return int_results_df


def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []
    skipped_xls_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Check that the .xls file is an HPLC report with an int result sheet
                try:
                    # Open the Excel file
                    wb = xlrd.open_workbook(file_path)
                    wb.sheet_by_name('IntResults1')
                
                # If error, skip this file and add it to the skipped list
                except xlrd.XLRDError:
                    skipped_xls_list.append(file_path)
                    print(file_path)
                    continue
                
                # Extract data from specific cells
                int_results_df = extract_data_from_file(file_path)
                
                # Append the extracted data to the respective lists
                int_results_df_list.append(int_results_df)

    if not int_results_df_list:
        print("No '.xls' files with 'IntResults1' sheet found.")
        return

    # Concatenate all DataFrames into a single DataFrame
    int_results_df_combined = pd.concat(int_results_df_list, ignore_index=True)
    
    # Define the sorting order
    sorting_order = ['Sequence', 'SeqLine']
    
    # Convert 'SeqLine' to integer type for sorting
    int_results_df_combined['SeqLine'] = int_results_df_combined['SeqLine'].astype(str)
    int_results_df_combined['SeqLine'] = int_results_df_combined['SeqLine'].apply(extract_numeric_part)
    
    # Sort the combined DataFrame by the specified order
    int_results_df_combined.sort_values(by=sorting_order, ascending=[False, True], inplace=True)
    
    # Print the extracted DataFrame
    # print("\nIntResults DataFrame:")
    # print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    file_name = "HPLC_Summary_" + parent_directory.rsplit("\\", 2)[-1] + ".csv"
    try:
        if int_results_df_combined['Sequence'].iloc[0] == int_results_df_combined['Sequence'].iloc[-1]:
            int_results_csv_path = os.path.join(parent_directory, file_name)
            int_results_df_combined.to_csv(int_results_csv_path, index=False)
    except:
        int_results_csv_path = os.path.join(parent_directory, "HPLC_Summary.csv")
        int_results_df_combined.to_csv(int_results_csv_path, index=False)
    
    # Print skipped file list
    print("Skipped files:", skipped_xls_list)
    
    # Print location of output file
    print(f"Results saved to: {int_results_csv_path}")
    
    # Input pause so user can see result path
    input("Press the <ENTER> key to continue...")

        
# Define a function to extract the numeric part from the SeqLine string
def extract_numeric_part(seqline):
    # Use regular expression to find the numeric part
    match = re.search(r'\d+', seqline)
    if match:
        return int(match.group())  # Return the numeric part as integer
    else:
        return 0  # If no numeric part found, return 0

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10
# WARNING *** file size (43135) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (43135) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38810) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38810) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34979) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34979) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34979) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34979) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34983) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34983) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39052) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39052) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (40596) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (40596) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37985) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37985) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39052) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39052) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35652) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35652) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37346) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37346) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39509) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39509) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39020) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39020) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37172) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37172) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38828) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38828) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35688) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35688) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37530) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37530) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38179) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38179) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38189) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38189) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37362) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (37362) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38828) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (38828) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (36539) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (36539) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39020) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (39020) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33521) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33521) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 170
#     167         return 0  # If no numeric part found, return 0
#     169 if __name__ == "__main__":
# --> 170     main()
#
# Cell In[2], line 114, in main()
#     111     continue
#     113 # Extract data from specific cells
# --> 114 int_results_df = extract_data_from_file(file_path)
#     116 # Append the extracted data to the respective lists
#     117 int_results_df_list.append(int_results_df)
#
# Cell In[2], line 81, in extract_data_from_file(file_path)
#      78 int_results_df = pd.DataFrame(rows_data)
#      80 # Convert SeqLine to string for mixed digit numbers
# ---> 81 int_results_df['SeqLine'] = int_results_df['SeqLine'].astype(str)
#      83 return int_results_df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:418, in RangeIndex.get_loc(self, key)
#     416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
# --> 418     raise KeyError(key)
#     419 self._check_indexing_error(key)
#     420 raise KeyError(key)
#
# KeyError: 'SeqLine'

# %%
# v2.1
# Added if multiple sequences are scraped to just name the csv the default name
# Added pause at end so user knows where file is saved
# Add DAD signal for each?
# Must use short or detail report, full does not have area percent
# Test with other column run data

import os
import xlrd
import pandas as pd
import re

def extract_data_from_file(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')

    # Extract data from Signal sheet
    signal_sheet = wb.sheet_by_name('Signal')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):
        # Extract Method from Sheet1 cell B6
        method = sheet1.cell_value(rowx=5, colx=1)  # B6
        
        # Extract Sequence from Sheet1 cell B5
        sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
        sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right

        # Extract File Name from Signal Sheet H2
        file_name_text = signal_sheet.cell_value(rowx=1, colx=7)  # H2
        file_name = file_name_text.rsplit("\\", 2)[-1]
        
        # Initialize dictionary for current row data
        row_data = {}

        # Add a column named 'SeqLine' with value equal to the sample name
        row_data['SeqLine'] = sheet1.cell_value(rowx=18, colx=1)  # B19
        
        # Add a column named 'Sample' with value equal to the sample name
        row_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
        
        # Add a column named 'Peak' with value equal to the current loop number n
        row_data['Peak'] = row

        # Check if column 22 has a value, set area percent accordingly
        try:
            area_percent = int_results_sheet.cell_value(rowx=row, colx=22)
        except IndexError:
            area_percent = ""
        row_data['Area_Percent'] = area_percent
        
        # Add other data columns recursively
        for col, label in zip(range(4, 9), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)

        
        # Add Sequence, Method, and File Name to row data
        row_data['Sequence'] = sequence
        row_data['File Name'] = file_name
        row_data['Method'] = method

        # Append the row data to the list
        rows_data.append(row_data)

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    # Convert SeqLine to string for mixed digit numbers
    int_results_df['SeqLine'] = int_results_df['SeqLine'].astype(str)

    return int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                int_results_df = extract_data_from_file(file_path)
                
                # Append the extracted data to the respective lists
                int_results_df_list.append(int_results_df)

    # Concatenate all DataFrames into a single DataFrame
    int_results_df_combined = pd.concat(int_results_df_list, ignore_index=True)
    
    # Define the sorting order
    sorting_order = ['Sequence', 'SeqLine']
    
    # Convert 'SeqLine' to integer type for sorting
    int_results_df_combined['SeqLine'] = int_results_df_combined['SeqLine'].astype(str)
    int_results_df_combined['SeqLine'] = int_results_df_combined['SeqLine'].apply(extract_numeric_part)
    
    # Sort the combined DataFrame by the specified order
    int_results_df_combined.sort_values(by=sorting_order, ascending=[False, True], inplace=True)
    
    # Print the extracted DataFrame
    # print("\nIntResults DataFrame:")
    # print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    file_name = "HPLC_Summary_" + parent_directory.rsplit("\\", 2)[-1] + ".csv"
    try:
        if int_results_df_combined['Sequence'].iloc[0] == int_results_df_combined['Sequence'].iloc[-1]:
            int_results_csv_path = os.path.join(parent_directory, file_name)
            int_results_df_combined.to_csv(int_results_csv_path, index=False)
    except:
        int_results_csv_path = os.path.join(parent_directory, "HPLC_Summary.csv")
        int_results_df_combined.to_csv(int_results_csv_path, index=False)
    
    #Print location of output file:
    print(f"Results saved to: {int_results_csv_path}")
    
    #Input pause so user can see result path:
    input("Press the <ENTER> key to continue...")
        
# Define a function to extract the numeric part from the SeqLine string
def extract_numeric_part(seqline):
    # Use regular expression to find the numeric part
    match = re.search(r'\d+', seqline)
    if match:
        return int(match.group())  # Return the numeric part as integer
    else:
        return 0  # If no numeric part found, return 0

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path: C:\Users\JoelTencer\OneDrive - Attovia\Weekly Schedule
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 148
#     145         return 0  # If no numeric part found, return 0
#     147 if __name__ == "__main__":
# --> 148     main()
#
# Cell In[2], line 106, in main()
#     103             int_results_df_list.append(int_results_df)
#     105 # Concatenate all DataFrames into a single DataFrame
# --> 106 int_results_df_combined = pd.concat(int_results_df_list, ignore_index=True)
#     108 # Define the sorting order
#     109 sorting_order = ['Sequence', 'SeqLine']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:380, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     377 elif copy and using_copy_on_write():
#     378     copy = False
# --> 380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#     383     ignore_index=ignore_index,
#     384     join=join,
#     385     keys=keys,
#     386     levels=levels,
#     387     names=names,
#     388     verify_integrity=verify_integrity,
#     389     copy=copy,
#     390     sort=sort,
#     391 )
#     393 return op.get_result()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:443, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     440 self.verify_integrity = verify_integrity
#     441 self.copy = copy
# --> 443 objs, keys = self._clean_keys_and_objs(objs, keys)
#     445 # figure out what our result ndim is going to be
#     446 ndims = self._get_ndims(objs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:505, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     502     objs_list = list(objs)
#     504 if len(objs_list) == 0:
# --> 505     raise ValueError("No objects to concatenate")
#     507 if keys is None:
#     508     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
# v2
# Added first sort by sequence name, second seqLine
# Add DAD signal for each?
# Must use short or detail report, full does not have area percent
# Test with other column run data

import os
import xlrd
import pandas as pd
import re

def extract_data_from_file(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')

    # Extract data from Signal sheet
    signal_sheet = wb.sheet_by_name('Signal')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):
        # Extract Method from Sheet1 cell B6
        method = sheet1.cell_value(rowx=5, colx=1)  # B6
        
        # Extract Sequence from Sheet1 cell B5
        sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
        sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right

        # Extract File Name from Signal Sheet H2
        file_name_text = signal_sheet.cell_value(rowx=1, colx=7)  # H2
        file_name = file_name_text.rsplit("\\", 2)[-1]
        
        # Initialize dictionary for current row data
        row_data = {}

        # Add a column named 'SeqLine' with value equal to the sample name
        row_data['SeqLine'] = sheet1.cell_value(rowx=18, colx=1)  # B19
        
        # Add a column named 'Sample' with value equal to the sample name
        row_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
        
        # Add a column named 'Peak' with value equal to the current loop number n
        row_data['Peak'] = row

        # Check if column 22 has a value, set area percent accordingly
        try:
            area_percent = int_results_sheet.cell_value(rowx=row, colx=22)
        except IndexError:
            area_percent = ""
        row_data['Area_Percent'] = area_percent
        
        # Add other data columns recursively
        for col, label in zip(range(4, 9), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)

        
        # Add Sequence, Method, and File Name to row data
        row_data['Sequence'] = sequence
        row_data['File Name'] = file_name
        row_data['Method'] = method

        # Append the row data to the list
        rows_data.append(row_data)

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    # Convert SeqLine to string for mixed digit numbers
    int_results_df['SeqLine'] = int_results_df['SeqLine'].astype(str)

    return int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                int_results_df = extract_data_from_file(file_path)
                
                # Append the extracted data to the respective lists
                int_results_df_list.append(int_results_df)

    # Concatenate all DataFrames into a single DataFrame
    int_results_df_combined = pd.concat(int_results_df_list, ignore_index=True)
    
    # Define the sorting order
    sorting_order = ['Sequence', 'SeqLine']
    
    # Convert 'SeqLine' to integer type for sorting
    int_results_df_combined['SeqLine'] = int_results_df_combined['SeqLine'].astype(str)
    int_results_df_combined['SeqLine'] = int_results_df_combined['SeqLine'].apply(extract_numeric_part)
    
    # Sort the combined DataFrame by the specified order
    int_results_df_combined.sort_values(by=sorting_order, ascending=[False, True], inplace=True)
    
    # Print the extracted DataFrame
    # print("\nIntResults DataFrame:")
    # print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    file_name = "HPLC_Summary_" + parent_directory.rsplit("\\", 2)[-1] + ".csv"
    try:
        int_results_csv_path = os.path.join(parent_directory, file_name)
        int_results_df_combined.to_csv(int_results_csv_path, index=False)
    except:
        int_results_csv_path = os.path.join(parent_directory, "HPLC_Summary.csv")
        int_results_df_combined.to_csv(int_results_csv_path, index=False)
    
    print(f"Results saved to: {int_results_csv_path}")
    
# Define a function to extract the numeric part from the SeqLine string
def extract_numeric_part(seqline):
    # Use regular expression to find the numeric part
    match = re.search(r'\d+', seqline)
    if match:
        return int(match.group())  # Return the numeric part as integer
    else:
        return 0  # If no numeric part found, return 0

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path: C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 05 06 ASYM IL13_HZ_4C12_2BB3_5D4 2024-05-06 14-29-28.zip\2024 05 06 ASYM IL13_HZ_4C12_2BB3_5D4 2024-05-06 14-29-28
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 133
#     130     print(f"Results saved to: {int_results_csv_path}")
#     132 if __name__ == "__main__":
# --> 133     main()
#     136 # Define a function to extract the numeric part from the SeqLine string
#     137 def extract_numeric_part(seqline):
#     138     # Use regular expression to find the numeric part
#
# Cell In[18], line 105, in main()
#     102             int_results_df_list.append(int_results_df)
#     104 # Concatenate all DataFrames into a single DataFrame
# --> 105 int_results_df_combined = pd.concat(int_results_df_list, ignore_index=True)
#     107 # Define the sorting order
#     108 sorting_order = ['Sequence', 'SeqLine']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:380, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     377 elif copy and using_copy_on_write():
#     378     copy = False
# --> 380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#     383     ignore_index=ignore_index,
#     384     join=join,
#     385     keys=keys,
#     386     levels=levels,
#     387     names=names,
#     388     verify_integrity=verify_integrity,
#     389     copy=copy,
#     390     sort=sort,
#     391 )
#     393 return op.get_result()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:443, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     440 self.verify_integrity = verify_integrity
#     441 self.copy = copy
# --> 443 objs, keys = self._clean_keys_and_objs(objs, keys)
#     445 # figure out what our result ndim is going to be
#     446 ndims = self._get_ndims(objs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:505, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     502     objs_list = list(objs)
#     504 if len(objs_list) == 0:
# --> 505     raise ValueError("No objects to concatenate")
#     507 if keys is None:
#     508     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
# v1.9
# Added SeqLine as first item then sort by seqLine
# Add DAD signal for each?
# Must use short or detail report, full does not have area percent
# Test with other column run data

import os
import xlrd
import pandas as pd
import re

def extract_data_from_file(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')

    # Extract data from Signal sheet
    signal_sheet = wb.sheet_by_name('Signal')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):
        # Extract Method from Sheet1 cell B6
        method = sheet1.cell_value(rowx=5, colx=1)  # B6
        
        # Extract Sequence from Sheet1 cell B5
        sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
        sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right

        # Extract File Name from Signal Sheet H2
        file_name_text = signal_sheet.cell_value(rowx=1, colx=7)  # H2
        file_name = file_name_text.rsplit("\\", 2)[-1]
        
        # Initialize dictionary for current row data
        row_data = {}

        # Add a column named 'SeqLine' with value equal to the sample name
        row_data['SeqLine'] = sheet1.cell_value(rowx=18, colx=1)  # B19
        
        # Add a column named 'Sample' with value equal to the sample name
        row_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
        
        # Add a column named 'Peak' with value equal to the current loop number n
        row_data['Peak'] = row

        # Check if column 22 has a value, set area percent accordingly
        try:
            area_percent = int_results_sheet.cell_value(rowx=row, colx=22)
        except IndexError:
            area_percent = ""
        row_data['Area_Percent'] = area_percent
        
        # Add other data columns recursively
        for col, label in zip(range(4, 9), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)

        
        # Add Sequence, Method, and File Name to row data
        row_data['Sequence'] = sequence
        row_data['File Name'] = file_name
        row_data['Method'] = method

        # Append the row data to the list
        rows_data.append(row_data)

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    # Convert SeqLine to string for mixed digit numbers
    int_results_df['SeqLine'] = int_results_df['SeqLine'].astype(str)

    return int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                int_results_df = extract_data_from_file(file_path)
                
                # Append the extracted data to the respective lists
                int_results_df_list.append(int_results_df)

    # Concatenate all DataFrames into a single DataFrame
    int_results_df_combined = pd.concat(int_results_df_list, ignore_index=True)
    
    # Sort the combined DataFrame by SeqLine
    int_results_df_combined['SeqLine'] = int_results_df_combined['SeqLine'].astype(str)
    int_results_df_combined['SeqLine'] = int_results_df_combined['SeqLine'].apply(extract_numeric_part)
    int_results_df_combined = int_results_df_combined.sort_values(by='SeqLine')
    
    # Print the extracted DataFrame
    # print("\nIntResults DataFrame:")
    # print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    file_name = "HPLC_Summary_" + parent_directory.rsplit("\\", 2)[-1] + ".csv"
    try:
        int_results_csv_path = os.path.join(parent_directory, file_name)
        int_results_df_combined.to_csv(int_results_csv_path, index=False)
    except:
        int_results_csv_path = os.path.join(parent_directory, "HPLC_Summary.csv")
        int_results_df_combined.to_csv(int_results_csv_path, index=False)
    
    print(f"Results saved to: {int_results_csv_path}")

# Define a function to extract the numeric part from the SeqLine string
def extract_numeric_part(seqline):
    # Use regular expression to find the numeric part
    match = re.search(r'\d+', seqline)
    if match:
        return int(match.group())  # Return the numeric part as integer
    else:
        return 0  # If no numeric part found, return 0

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path: C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 05 06 ASYM IL13_HZ_4C12_2BB3_5D4 2024-05-06 14-29-28.zip\2024 05 06 ASYM IL13_HZ_4C12_2BB3_5D4 2024-05-06 14-29-28
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 137
#     134         return 0  # If no numeric part found, return 0
#     136 if __name__ == "__main__":
# --> 137     main()
#
# Cell In[19], line 105, in main()
#     102             int_results_df_list.append(int_results_df)
#     104 # Concatenate all DataFrames into a single DataFrame
# --> 105 int_results_df_combined = pd.concat(int_results_df_list, ignore_index=True)
#     107 # Sort the combined DataFrame by SeqLine
#     108 int_results_df_combined['SeqLine'] = int_results_df_combined['SeqLine'].astype(str)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:380, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     377 elif copy and using_copy_on_write():
#     378     copy = False
# --> 380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#     383     ignore_index=ignore_index,
#     384     join=join,
#     385     keys=keys,
#     386     levels=levels,
#     387     names=names,
#     388     verify_integrity=verify_integrity,
#     389     copy=copy,
#     390     sort=sort,
#     391 )
#     393 return op.get_result()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:443, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     440 self.verify_integrity = verify_integrity
#     441 self.copy = copy
# --> 443 objs, keys = self._clean_keys_and_objs(objs, keys)
#     445 # figure out what our result ndim is going to be
#     446 ndims = self._get_ndims(objs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:505, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     502     objs_list = list(objs)
#     504 if len(objs_list) == 0:
# --> 505     raise ValueError("No objects to concatenate")
#     507 if keys is None:
#     508     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
# v1.8
# Added parent folder to file name of report, if error just call HPLC Summary Report
# changed where sequence name is taken from Sheet1 B15 to Sheet1 B5
# Add DAD signal for each?
# Look into full report save options, why was fileinfo1 sheet in one thing and not another, check all are the same
# Test with other column run data

import os
import xlrd
import pandas as pd

def extract_data_from_file(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')

    #Extract data from FileInfo1 sheet
    #fileinfo1_sheet = wb.sheet_by_name('FileInfo1')

    # Extract data from Signal sheet
    signal_sheet = wb.sheet_by_name('Signal')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):
        # Extract Method from Sheet1 cell B6
        method = sheet1.cell_value(rowx=5, colx=1)  # B6
        
        # Extract Sequence from Sheet1 cell B5
        sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
        sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right

        # Extract file name from FileInfo1 cell D2
        #file_name = fileinfo1_sheet.cell_value(rowx=1, colx=3)  # D2

        # Extract File Name from Signal Sheet H2
        file_name_text = signal_sheet.cell_value(rowx=1, colx=7)  # H2
        file_name = file_name_text.rsplit("\\", 2)[-1]
        
        
        # Initialize dictionary for current row data
        row_data = {}

        # Add a column named 'Sample' with value equal to the sample name
        row_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
        
        # Add a column named 'Peak' with value equal to the current loop number n
        row_data['Peak'] = row

        # Check if column 22 has a value, set area percent accordingly
        try:
            area_percent = int_results_sheet.cell_value(rowx=row, colx=22)
        except IndexError:
            area_percent = ""
        row_data['Area_Percent'] = area_percent
        
        # Add other data columns recursively
        for col, label in zip(range(4, 9), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)

        
        # Add Sequence, Method, and File Name to row data
        row_data['Sequence'] = sequence
        row_data['File Name'] = file_name
        row_data['Method'] = method

        # Append the row data to the list
        rows_data.append(row_data)

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)
   # print('First loop: ', int_results_df)

    return int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                int_results_df = extract_data_from_file(file_path)
                
                # Append the extracted data to the respective lists
                int_results_df_list.append(int_results_df)
                #print('Main Loop: ', int_results_df)

    # Concatenate all DataFrames into a single DataFrame
    int_results_df_combined = pd.concat(int_results_df_list, ignore_index=True)
    
    # Print the extracted DataFrame
   # print("\nIntResults Dataframe:")
   # print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    file_name = "HPLC_Summary_" + parent_directory.rsplit("\\", 2)[-1] + ".csv"
    try:
        int_results_csv_path = os.path.join(parent_directory, file_name)
        int_results_df_combined.to_csv(int_results_csv_path, index=False)
    except:
        int_results_csv_path = os.path.join(parent_directory, "HPLC_Summary.csv")
        int_results_df_combined.to_csv(int_results_csv_path, index=False)
    
   # print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28\2AB-0401.D
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
# v1.7
# changed where sequence name is taken from Sheet1 B15 to Sheet1 B5
# Add DAD signal for each?
# Look into full report save options, why was fileinfo1 sheet in one thing and not another, check all are the same
# Test with other column run data

import os
import xlrd
import pandas as pd

def extract_data_from_file(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')

    #Extract data from FileInfo1 sheet
    #fileinfo1_sheet = wb.sheet_by_name('FileInfo1')

    # Extract data from Signal sheet
    signal_sheet = wb.sheet_by_name('Signal')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):
        # Extract Method from Sheet1 cell B6
        method = sheet1.cell_value(rowx=5, colx=1)  # B6
        
        # Extract Sequence from Sheet1 cell B5
        sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
        sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right

        # Extract file name from FileInfo1 cell D2
        #file_name = fileinfo1_sheet.cell_value(rowx=1, colx=3)  # D2

        # Extract File Name from Signal Sheet H2
        file_name_text = signal_sheet.cell_value(rowx=1, colx=7)  # H2
        file_name = file_name_text.rsplit("\\", 2)[-1]
        
        
        # Initialize dictionary for current row data
        row_data = {}

        # Add a column named 'Sample' with value equal to the sample name
        row_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
        
        # Add a column named 'Peak' with value equal to the current loop number n
        row_data['Peak'] = row

        # Check if column 22 has a value, set area percent accordingly
        try:
            area_percent = int_results_sheet.cell_value(rowx=row, colx=22)
        except IndexError:
            area_percent = ""
        row_data['Area_Percent'] = area_percent
        
        # Add other data columns recursively
        for col, label in zip(range(4, 9), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)

        
        # Add Sequence, Method, and File Name to row data
        row_data['Sequence'] = sequence
        row_data['File Name'] = file_name
        row_data['Method'] = method

        # Append the row data to the list
        rows_data.append(row_data)

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)
   # print('First loop: ', int_results_df)

    return int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                int_results_df = extract_data_from_file(file_path)
                
                # Append the extracted data to the respective lists
                int_results_df_list.append(int_results_df)
                #print('Main Loop: ', int_results_df)

    # Concatenate all DataFrames into a single DataFrame
    int_results_df_combined = pd.concat(int_results_df_list, ignore_index=True)
    
    # Print the extracted DataFrame
   # print("\nIntResults Dataframe:")
   # print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "HPLC_Summary.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
   # print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()

# %%
# v1.6
# removed baseline, timestart, timeend, etc.
# Look into full report save options, why was fileinfo1 sheet in one thing and not another, check all are the same
# Test with other column run data

import os
import xlrd
import pandas as pd

def extract_data_from_file(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')

    #Extract data from FileInfo1 sheet
    #fileinfo1_sheet = wb.sheet_by_name('FileInfo1')

    # Extract data from Signal sheet
    signal_sheet = wb.sheet_by_name('Signal')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):
        # Extract Method from Sheet1 cell B6
        method = sheet1.cell_value(rowx=5, colx=1)  # B6
        
        # Extract Sequence from Sheet1 cell B5
        sequence_text = sheet1.cell_value(rowx=14, colx=1)  # B15
        sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right

        # Extract file name from FileInfo1 cell D2
        #file_name = fileinfo1_sheet.cell_value(rowx=1, colx=3)  # D2

        # Extract File Name from Signal Sheet H2
        file_name_text = signal_sheet.cell_value(rowx=1, colx=7)  # H2
        file_name = file_name_text.rsplit("\\", 2)[-1]
        
        
        # Initialize dictionary for current row data
        row_data = {}

        # Add a column named 'Sample' with value equal to the sample name
        row_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
        
        # Add a column named 'Peak' with value equal to the current loop number n
        row_data['Peak'] = row

        # Check if column 22 has a value, set area percent accordingly
        try:
            area_percent = int_results_sheet.cell_value(rowx=row, colx=22)
        except IndexError:
            area_percent = ""
        row_data['Area_Percent'] = area_percent
        
        # Add other data columns recursively
        for col, label in zip(range(4, 9), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)

        
        # Add Sequence, Method, and File Name to row data
        row_data['Sequence'] = sequence
        row_data['File Name'] = file_name
        row_data['Method'] = method

        # Append the row data to the list
        rows_data.append(row_data)

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)
   # print('First loop: ', int_results_df)

    return int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                int_results_df = extract_data_from_file(file_path)
                
                # Append the extracted data to the respective lists
                int_results_df_list.append(int_results_df)
                #print('Main Loop: ', int_results_df)

    # Concatenate all DataFrames into a single DataFrame
    int_results_df_combined = pd.concat(int_results_df_list, ignore_index=True)
    
    # Print the extracted DataFrame
   # print("\nIntResults Dataframe:")
   # print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "HPLC_Results_Summary.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
   # print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path: C:\Users\JoelTencer\Documents\HPLC\full report
# WARNING *** file size (38961) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 118
#     115    # print(f"IntResults DataFrame saved to: {int_results_csv_path}")
#     117 if __name__ == "__main__":
# --> 118     main()
#
# Cell In[1], line 99, in main()
#      96 file_path = os.path.join(root, file)
#      98 # Extract data from specific cells
# ---> 99 int_results_df = extract_data_from_file(file_path)
#     101 # Append the extracted data to the respective lists
#     102 int_results_df_list.append(int_results_df)
#
# Cell In[1], line 39, in extract_data_from_file(file_path)
#      37 # Extract Sequence from Sheet1 cell B5
#      38 sequence_text = sheet1.cell_value(rowx=14, colx=1)  # B15
# ---> 39 sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right
#      41 # Extract file name from FileInfo1 cell D2
#      42 #file_name = fileinfo1_sheet.cell_value(rowx=1, colx=3)  # D2
#      43
#      44 # Extract File Name from Signal Sheet H2
#      45 file_name_text = signal_sheet.cell_value(rowx=1, colx=7)  # H2
#
# IndexError: list index out of range

# %%
# v1.5
# mains has a loop that re-defines the same exact data unnecesarily, remove for clarity and speed
# Look into full report save options, why was fileinfo1 sheet in one thing and not another, check all are the same
# Test with other column run data

import os
import xlrd
import pandas as pd

def extract_data_from_file(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')

    #Extract data from FileInfo1 sheet
    #fileinfo1_sheet = wb.sheet_by_name('FileInfo1')

    # Extract data from Signal sheet
    signal_sheet = wb.sheet_by_name('Signal')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):
        # Extract Method from Sheet1 cell B6
        method = sheet1.cell_value(rowx=5, colx=1)  # B6
        
        # Extract Sequence from Sheet1 cell B5
        sequence_text = sheet1.cell_value(rowx=14, colx=1)  # B15
        sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right

        # Extract file name from FileInfo1 cell D2
        #file_name = fileinfo1_sheet.cell_value(rowx=1, colx=3)  # D2

        # Extract File Name from Signal Sheet H2
        file_name_text = signal_sheet.cell_value(rowx=1, colx=7)  # H2
        file_name = file_name_text.rsplit("\\", 2)[-1]
        
        
        # Initialize dictionary for current row data
        row_data = {}

        # Add a column named 'Sample' with value equal to the sample name
        row_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
        
        # Add a column named 'Peak' with value equal to the current loop number n
        row_data['Peak'] = row

        # Check if column 22 has a value, set area percent accordingly
        try:
            area_percent = int_results_sheet.cell_value(rowx=row, colx=22)
        except IndexError:
            area_percent = ""
        row_data['Area_Percent'] = area_percent
        
        # Add other data columns recursively
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)

        
        # Add Sequence, Method, and File Name to row data
        row_data['Sequence'] = sequence
        row_data['File Name'] = file_name
        row_data['Method'] = method

        # Append the row data to the list
        rows_data.append(row_data)

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)
   # print('First loop: ', int_results_df)

    return int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                int_results_df = extract_data_from_file(file_path)
                
                # Append the extracted data to the respective lists
                int_results_df_list.append(int_results_df)
                #print('Main Loop: ', int_results_df)

    # Concatenate all DataFrames into a single DataFrame
    int_results_df_combined = pd.concat(int_results_df_list, ignore_index=True)
    
    # Print the extracted DataFrame
   # print("\nIntResults Dataframe:")
   # print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "HPLC_Results_Summary.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
   # print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 05 03 769-773 RERUN 2024-05-03 12-44-02
# WARNING *** file size (36491) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33958) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (34801) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (33958) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35654) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35654) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35654) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (35654) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
import os
import xlrd
import pandas as pd

def extract_data_from_file(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):
        # Initialize dictionary for current row data
        row_data = {}

        # Add a column named 'Sample' with value equal to the sample name
        row_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
        
        # Add a column named 'Peak' with value equal to the current loop number n
        row_data['Peak'] = row

        # Extract Method from Sheet1 cell B6
        method = sheet1.cell_value(rowx=5, colx=1)  # B6
        
        # Extract Sequence from Sheet1 cell B5
       # sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
       # sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right
            

        # Check if column 22 has a value, set area percent accordingly
        try:
            area_percent = int_results_sheet.cell_value(rowx=row, colx=22)
        except IndexError:
            area_percent = ""
        row_data['Area_Percent'] = area_percent
        
        # Add other data columns recursively
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)

        # Append the row data to the list
        rows_data.append(row_data)

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    return int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    # for root, dirs, files in os.walk(parent_directory):
    #    for file in files:
    #        if file.endswith(".xls"):
    #            file_path = os.path.join(root, file)
    #            
    #            # Extract data from specific cells
    #            int_results_df = extract_data_from_file(file_path)
    #            
                # Append the extracted data to the list
                int_results_df_list.append(int_results_df)

    # Concatenate all DataFrames into a single DataFrame
    int_results_df_combined = pd.concat(int_results_df_list, ignore_index=True)
    
    # Print the extracted DataFrame
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "int_results.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28
# WARNING *** file size (32454) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[65], line 90
#      87     print(f"IntResults DataFrame saved to: {int_results_csv_path}")
#      89 if __name__ == "__main__":
# ---> 90     main()
#
# Cell In[65], line 72, in main()
#      69 file_path = os.path.join(root, file)
#      71 # Extract data from specific cells
# ---> 72 int_results_df = extract_data_from_file(file_path)
#      74 # Append the extracted data to the list
#      75 int_results_df_list.append(int_results_df)
#
# Cell In[65], line 34, in extract_data_from_file(file_path)
#      32 # Extract Sequence, Method, and File Name
#      33 for i, label in enumerate(['Sequence', 'Method', 'File Name']):
# ---> 34     cell_value = sheet1.cell_value(rowx=row, colx=i)  # Columns 0, 1, 2
#      35     if i == 0:  # For Sequence
#      36         cell_value = cell_value.rsplit("\\", 2)[-2] if "\\" in cell_value else cell_value
#
# File ~\anaconda3\Lib\site-packages\xlrd\sheet.py:420, in Sheet.cell_value(self, rowx, colx)
#     418 def cell_value(self, rowx, colx):
#     419     "Value of the cell in the given row and column."
# --> 420     return self._cell_values[rowx][colx]
#
# IndexError: list index out of range

# %%
# not iterating on right cell for file name, sequence, and method but has recursive loops setup

import os
import xlrd
import pandas as pd

def extract_data_from_file(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):
        # Initialize dictionary for current row data
        row_data = {}

        # Add a column named 'Sample' with value equal to the sample name
        row_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
        
        # Add a column named 'Peak' with value equal to the current loop number n
        row_data['Peak'] = row

        # Extract Sequence, Method, and File Name
        for col, label in zip([1, 1, 1], ['Sequence', 'Method', 'File Name']):
            cell_value = sheet1.cell_value(rowx=row, colx=col)
            if col == 1:  # For Sequence and Method
                cell_value = cell_value.rsplit("\\", 2)[-2] if "\\" in cell_value else cell_value
            row_data[label] = cell_value

        # Check if column 22 has a value, set area percent accordingly
        try:
            area_percent = int_results_sheet.cell_value(rowx=row, colx=22)
        except IndexError:
            area_percent = ""
        row_data['Area_Percent'] = area_percent
        
        # Add other data columns recursively
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)

        # Append the row data to the list
        rows_data.append(row_data)

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    return int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                int_results_df = extract_data_from_file(file_path)
                
                # Append the extracted data to the list
                int_results_df_list.append(int_results_df)

    # Concatenate all DataFrames into a single DataFrame
    int_results_df_combined = pd.concat(int_results_df_list, ignore_index=True)
    
    # Print the extracted DataFrame
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "int_results.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28
# WARNING *** file size (32454) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32031) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32031) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (36244) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 90
#      87     print(f"IntResults DataFrame saved to: {int_results_csv_path}")
#      89 if __name__ == "__main__":
# ---> 90     main()
#
# Cell In[63], line 72, in main()
#      69 file_path = os.path.join(root, file)
#      71 # Extract data from specific cells
# ---> 72 int_results_df = extract_data_from_file(file_path)
#      74 # Append the extracted data to the list
#      75 int_results_df_list.append(int_results_df)
#
# Cell In[63], line 36, in extract_data_from_file(file_path)
#      34     cell_value = sheet1.cell_value(rowx=row, colx=col)
#      35     if col == 1:  # For Sequence and Method
# ---> 36         cell_value = cell_value.rsplit("\\", 2)[-2] if "\\" in cell_value else cell_value
#      37     row_data[label] = cell_value
#      39 # Check if column 22 has a value, set area percent accordingly
#
# TypeError: argument of type 'float' is not iterable

# %%
# need to change so it iterates through file name, method, and sequence somehow in nested or double loop

import os
import xlrd
import pandas as pd

def extract_data_from_file(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):
        # Extract Method from Sheet1 cell B6
        method = sheet1.cell_value(rowx=5, colx=1)  # B6
        
        # Extract Sequence from Sheet1 cell B5
        sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
        sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right

        # Extract file name from Sheet1 cell B33
        file_name_text = sheet1.cell_value(rowx=32, colx=1)  # B33
        file_name = file_name_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right
        
        # Initialize dictionary for current row data
        row_data = {}

        # Add a column named 'Sample' with value equal to the sample name
        row_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
        
        # Add a column named 'Peak' with value equal to the current loop number row
        row_data['Peak'] = row
        
        # Add Sequence, Method, and File Name to row data
        # row_data['Sequence'] = sequence[row]
        # row_data['Method' = method
        # row_data['File Name'] = file_name


        # Check if column 22 has a value, set area percent accordingly
        try:
            area_percent = int_results_sheet.cell_value(rowx=row, colx=22)
        except IndexError:
            area_percent = ""
        row_data['Area_Percent'] = area_percent
        
        # Add other data columns recursively
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)
            # Add Sequence, Method, and File Name to row data
            row_data['Sequence'] = sequence[col]
            row_data['Method'] = method[col]
            row_data['File Name'] = file_name[col]

        # Append the row data to the list
        rows_data.append(row_data)

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    return int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                int_results_df = extract_data_from_file(file_path)
                
                # Append the extracted data to the list
                int_results_df_list.append(int_results_df)

    # Concatenate all DataFrames into a single DataFrame
    int_results_df_combined = pd.concat(int_results_df_list, ignore_index=True)
    
    # Print the extracted DataFrame
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "int_results.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28
# WARNING *** file size (32454) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[72], line 104
#     101     print(f"IntResults DataFrame saved to: {int_results_csv_path}")
#     103 if __name__ == "__main__":
# --> 104     main()
#
# Cell In[72], line 86, in main()
#      83 file_path = os.path.join(root, file)
#      85 # Extract data from specific cells
# ---> 86 int_results_df = extract_data_from_file(file_path)
#      88 # Append the extracted data to the list
#      89 int_results_df_list.append(int_results_df)
#
# Cell In[72], line 62, in extract_data_from_file(file_path)
#      60     row_data['Sequence'] = sequence[col]
#      61     row_data['Method'] = method[col]
# ---> 62     row_data['File Name'] = file_name[col]
#      64 # Append the row data to the list
#      65 rows_data.append(row_data)
#
# IndexError: string index out of range

# %%
import os
import xlrd
import pandas as pd

def extract_data_from_file(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):
        # Extract Method from Sheet1 cell B6
        method = sheet1.cell_value(rowx=5, colx=1)  # B6
        
        # Extract Sequence from Sheet1 cell B5
        sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
        sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right

        # Extract file name from Sheet1 cell B33
        file_name_text = sheet1.cell_value(rowx=32, colx=1)  # B33
        file_name = file_name_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right
        
        # Initialize dictionary for current row data
        row_data = {}

        # Add a column named 'Sample' with value equal to the sample name
        row_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
        
        # Add a column named 'Peak' with value equal to the current loop number n
        row_data['Peak'] = row

        # Add Sequence, Method, and File Name to row data
        row_data['Sequence'] = sequence
        row_data['Method'] = method
        row_data['File Name'] = file_name

        # Check if column 22 has a value, set area percent accordingly
        try:
            area_percent = int_results_sheet.cell_value(rowx=row, colx=22)
        except IndexError:
            area_percent = ""
        row_data['Area_Percent'] = area_percent
        
        # Add other data columns recursively
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)

        # Append the row data to the list
        rows_data.append(row_data)

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    return int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                int_results_df = extract_data_from_file(file_path)
                
                # Append the extracted data to the respective lists
                int_results_df_list.append(int_results_df)

    # Concatenate all DataFrames into a single DataFrame
    int_results_df_combined = pd.concat(int_results_df_list, ignore_index=True)
    
    # Print the extracted DataFrame
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "int_results.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28
# WARNING *** file size (32454) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32031) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32031) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (36244) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
#
# IntResults Dataframe:
#      Sample  Peak                                           Sequence  \
# 0   770 1A3     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 1   770 1A4     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 2   771 1A6     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 3   771 1A7     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 4   771 1A8     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 5   771 1A9     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 6   772 1A2     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 7   773 1A3     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 8   773 1A3     2  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 9   773 1A4     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 10  773 1A4     2  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 11   ladder     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 12   ladder     2  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 13   ladder     3  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 14   ladder     4  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 15   ladder     5  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 16   ladder     6  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 17   ladder     7  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 18  769 1A5     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 19  769 1A6     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
#
#               Method   File Name Area_Percent   RetTime         Area  \
# 0   LHN SEC2 150MM.M  003-0101.D        100.0  3.727754   984.238464
# 1   LHN SEC2 150MM.M  003-0101.D               3.728524  1372.649902
# 2   LHN SEC2 150MM.M  003-0101.D               3.737285   630.557251
# 3   LHN SEC2 150MM.M  003-0101.D               3.740605  1003.827087
# 4   LHN SEC2 150MM.M  003-0101.D               3.739514  1133.794067
# 5   LHN SEC2 150MM.M  003-0101.D               3.735433  1190.986572
# 6   LHN SEC2 150MM.M  003-0101.D               3.880362  1505.992920
# 7   LHN SEC2 150MM.M  003-0101.D               3.431879    32.277645
# 8   LHN SEC2 150MM.M  003-0101.D               3.909431  3366.864258
# 9   LHN SEC2 150MM.M  003-0101.D               3.425463    25.783243
# 10  LHN SEC2 150MM.M  003-0101.D               3.903389  3165.020752
# 11  LHN SEC2 150MM.M  003-0101.D               2.629555   106.284401
# 12  LHN SEC2 150MM.M  003-0101.D               2.962707   455.443756
# 13  LHN SEC2 150MM.M  003-0101.D               3.230931   264.975800
# 14  LHN SEC2 150MM.M  003-0101.D               3.722415  1017.263245
# 15  LHN SEC2 150MM.M  003-0101.D               4.433238   647.048218
# 16  LHN SEC2 150MM.M  003-0101.D               5.141259   215.237579
# 17  LHN SEC2 150MM.M  003-0101.D               5.902357   122.673340
# 18  LHN SEC2 150MM.M  003-0101.D               3.774630   831.223694
# 19  LHN SEC2 150MM.M  003-0101.D               3.766405   984.708984
#
#         Height     Width  Symmetry   Baseline  TimeStart    LevelStart  \
# 0    60.824165  0.234787  0.480896   0.244937   3.423667  0.000000e+00
# 1    83.099113  0.238713  0.467937   0.311448   3.431833  0.000000e+00
# 2    39.012695  0.232567  0.450151   0.154830   3.440000 -1.110223e-16
# 3    62.330482  0.231891  0.458167   0.224058   3.449333  0.000000e+00
# 4    70.732391  0.231009  0.457887   0.254438   3.450000  0.000000e+00
# 5    75.818275  0.225265  0.457970   0.193658   3.448333  1.110223e-16
# 6    91.681450  0.235641  0.507016   0.120164   2.869500  0.000000e+00
# 7     2.137722  0.226156  0.964086   0.177019   2.857333  0.000000e+00
# 8   203.777313  0.236760  0.469107   0.272233   3.616299  8.355163e-01
# 9     1.786172  0.220407  0.936864   0.145032   3.019167  0.000000e+00
# 10  196.009232  0.232385  0.465447   0.238227   3.608056  6.647950e-01
# 11    6.798275  0.228397  1.765334  -2.602099   2.212000  0.000000e+00
# 12   25.940151  0.254837  0.867126  -4.687346   2.730381  6.832913e+00
# 13   16.417297  0.226300  0.294813  -6.366199   3.166339  1.556556e+01
# 14   36.858269  0.373992  0.476035  -9.442472   3.471915  1.210374e+01
# 15   34.472748  0.258982  0.930943 -13.891619   4.215693  1.707800e+01
# 16    5.513213  0.467470  5.577894  -5.279715   4.732000  0.000000e+00
# 17    7.320348  0.257508  1.150406   0.083779   5.338666  0.000000e+00
# 18   48.074066  0.251722  0.475215   0.222987   3.479000 -1.110223e-16
# 19   58.291908  0.243082  0.460855   0.201744   3.475833  0.000000e+00
#
#     BaselineStart   TimeEnd
# 0        0.217915  5.183667
# 1        0.378132  5.305167
# 2        0.226974  5.306667
# 3        0.296116  5.309333
# 4        0.320435  5.303333
# 5        0.265598  5.314697
# 6        0.020504  5.336167
# 7        0.062466  3.616299
# 8        0.213789  5.639555
# 9        0.065804  3.608056
# 10       0.180637  5.633611
# 11       0.011444  2.730381
# 12      -3.233181  3.166339
# 13      -5.961906  3.471915
# 14      -7.874552  4.215693
# 15     -12.529979  4.725333
# 16     -15.654564  5.330889
# 17      -0.467300  6.286445
# 18       0.291824  5.305666
# 19       0.270367  5.309166
# IntResults DataFrame saved to: C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28\int_results.csv

# %%
#not extracting file name method and sequence right only taking from first

import os
import xlrd
import pandas as pd

def extract_data_from_cells(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Initialize dictionaries to store extracted data
    sample_data = {}
    int_results_data = {}

    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    sample_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26

    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):
        # Extract Method from Sheet1 cell B6
        method = sheet1.cell_value(rowx=5, colx=1)  # B6
        
        # Extract Sequence from Sheet1 cell B5
        sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
        sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right

        # Extract file name from Sheet1 cell B33
        file_name_text = sheet1.cell_value(rowx=32, colx=1)  # B33
        file_name = file_name_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right
        
        # Initialize dictionary for current row data
        row_data = {}

        # Add a column named 'Sample' with value equal to the sample name
        int_results_data['Sample'] = sample_data['Sample']
        
        # Add a column named 'Peak' with value equal to the current loop number n
        int_results_data['Peak'] = row

        # Add Sequence, Method, and File Name to row data
        int_results_data['Sequence'] = sequence
        int_results_data['Method'] = method
        int_results_data['File Name'] = file_name

        # Check if column 22 has a value, set area percent accordingly
        try:
            area_percent = int_results_sheet.cell_value(rowx=row, colx=22)
        except IndexError:
            area_percent = ""
        int_results_data['Area_Percent'] = area_percent
        
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)

        
        # Append the row data to the list
        rows_data.append({**int_results_data, **row_data})

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    return sample_data, int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                sample_data, int_results_df = extract_data_from_cells(file_path)
                
                # Append the extracted data to the respective lists
                sample_data_list.append(sample_data)
                int_results_df_list.append(int_results_df)

    # Convert the extracted data into dataframes
    sample_df = pd.DataFrame(sample_data_list)
    int_results_df_combined = pd.concat(int_results_df_list)
    
    # Print the extracted dataframes
    print("Sample Dataframe:")
    print(sample_df)
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "int_results.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28
# WARNING *** file size (32454) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32031) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32031) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (36244) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Sample Dataframe:
#      Sample
# 0   770 1A3
# 1   770 1A4
# 2   771 1A6
# 3   771 1A7
# 4   771 1A8
# 5   771 1A9
# 6   772 1A2
# 7   773 1A3
# 8   773 1A4
# 9    ladder
# 10  769 1A5
# 11  769 1A6
#
# IntResults Dataframe:
#     Sample  Peak                                           Sequence  \
# 0  770 1A3     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 0  770 1A4     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 0  771 1A6     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 0  771 1A7     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 0  771 1A8     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 0  771 1A9     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 0  772 1A2     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 0  773 1A3     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 1  773 1A3     2  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 0  773 1A4     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 1  773 1A4     2  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 0   ladder     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 1   ladder     2  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 2   ladder     3  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 3   ladder     4  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 4   ladder     5  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 5   ladder     6  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 6   ladder     7  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 0  769 1A5     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
# 0  769 1A6     1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...
#
#              Method   File Name Area_Percent   RetTime         Area  \
# 0  LHN SEC2 150MM.M  003-0101.D        100.0  3.727754   984.238464
# 0  LHN SEC2 150MM.M  003-0101.D               3.728524  1372.649902
# 0  LHN SEC2 150MM.M  003-0101.D               3.737285   630.557251
# 0  LHN SEC2 150MM.M  003-0101.D               3.740605  1003.827087
# 0  LHN SEC2 150MM.M  003-0101.D               3.739514  1133.794067
# 0  LHN SEC2 150MM.M  003-0101.D               3.735433  1190.986572
# 0  LHN SEC2 150MM.M  003-0101.D               3.880362  1505.992920
# 0  LHN SEC2 150MM.M  003-0101.D               3.431879    32.277645
# 1  LHN SEC2 150MM.M  003-0101.D               3.909431  3366.864258
# 0  LHN SEC2 150MM.M  003-0101.D               3.425463    25.783243
# 1  LHN SEC2 150MM.M  003-0101.D               3.903389  3165.020752
# 0  LHN SEC2 150MM.M  003-0101.D               2.629555   106.284401
# 1  LHN SEC2 150MM.M  003-0101.D               2.962707   455.443756
# 2  LHN SEC2 150MM.M  003-0101.D               3.230931   264.975800
# 3  LHN SEC2 150MM.M  003-0101.D               3.722415  1017.263245
# 4  LHN SEC2 150MM.M  003-0101.D               4.433238   647.048218
# 5  LHN SEC2 150MM.M  003-0101.D               5.141259   215.237579
# 6  LHN SEC2 150MM.M  003-0101.D               5.902357   122.673340
# 0  LHN SEC2 150MM.M  003-0101.D               3.774630   831.223694
# 0  LHN SEC2 150MM.M  003-0101.D               3.766405   984.708984
#
#        Height     Width  Symmetry   Baseline  TimeStart    LevelStart  \
# 0   60.824165  0.234787  0.480896   0.244937   3.423667  0.000000e+00
# 0   83.099113  0.238713  0.467937   0.311448   3.431833  0.000000e+00
# 0   39.012695  0.232567  0.450151   0.154830   3.440000 -1.110223e-16
# 0   62.330482  0.231891  0.458167   0.224058   3.449333  0.000000e+00
# 0   70.732391  0.231009  0.457887   0.254438   3.450000  0.000000e+00
# 0   75.818275  0.225265  0.457970   0.193658   3.448333  1.110223e-16
# 0   91.681450  0.235641  0.507016   0.120164   2.869500  0.000000e+00
# 0    2.137722  0.226156  0.964086   0.177019   2.857333  0.000000e+00
# 1  203.777313  0.236760  0.469107   0.272233   3.616299  8.355163e-01
# 0    1.786172  0.220407  0.936864   0.145032   3.019167  0.000000e+00
# 1  196.009232  0.232385  0.465447   0.238227   3.608056  6.647950e-01
# 0    6.798275  0.228397  1.765334  -2.602099   2.212000  0.000000e+00
# 1   25.940151  0.254837  0.867126  -4.687346   2.730381  6.832913e+00
# 2   16.417297  0.226300  0.294813  -6.366199   3.166339  1.556556e+01
# 3   36.858269  0.373992  0.476035  -9.442472   3.471915  1.210374e+01
# 4   34.472748  0.258982  0.930943 -13.891619   4.215693  1.707800e+01
# 5    5.513213  0.467470  5.577894  -5.279715   4.732000  0.000000e+00
# 6    7.320348  0.257508  1.150406   0.083779   5.338666  0.000000e+00
# 0   48.074066  0.251722  0.475215   0.222987   3.479000 -1.110223e-16
# 0   58.291908  0.243082  0.460855   0.201744   3.475833  0.000000e+00
#
#    BaselineStart   TimeEnd
# 0       0.217915  5.183667
# 0       0.378132  5.305167
# 0       0.226974  5.306667
# 0       0.296116  5.309333
# 0       0.320435  5.303333
# 0       0.265598  5.314697
# 0       0.020504  5.336167
# 0       0.062466  3.616299
# 1       0.213789  5.639555
# 0       0.065804  3.608056
# 1       0.180637  5.633611
# 0       0.011444  2.730381
# 1      -3.233181  3.166339
# 2      -5.961906  3.471915
# 3      -7.874552  4.215693
# 4     -12.529979  4.725333
# 5     -15.654564  5.330889
# 6      -0.467300  6.286445
# 0       0.291824  5.305666
# 0       0.270367  5.309166
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[57], line 111
#     108     print(f"IntResults DataFrame saved to: {int_results_csv_path}")
#     110 if __name__ == "__main__":
# --> 111     main()
#
# Cell In[57], line 107, in main()
#     105 # Save IntResults DataFrame to CSV
#     106 int_results_csv_path = os.path.join(parent_directory, "int_results.csv")
# --> 107 int_results_df_combined.to_csv(int_results_csv_path, index=False)
#     108 print(f"IntResults DataFrame saved to: {int_results_csv_path}")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
#    3906     encoding=encoding,
#    3907     errors=errors,
#    3908     compression=compression,
#    3909     quoting=quoting,
#    3910     columns=columns,
#    3911     index_label=index_label,
#    3912     mode=mode,
#    3913     chunksize=chunksize,
#    3914     quotechar=quotechar,
#    3915     date_format=date_format,
#    3916     doublequote=doublequote,
#    3917     escapechar=escapechar,
#    3918     storage_options=storage_options,
#    3919 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1152, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1131     created_buffer = False
#    1133 csv_formatter = CSVFormatter(
#    1134     path_or_buf=path_or_buf,
#    1135     lineterminator=lineterminator,
#    (...)
#    1150     formatter=self.fmt,
#    1151 )
# -> 1152 csv_formatter.save()
#    1154 if created_buffer:
#    1155     assert isinstance(path_or_buf, StringIO)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:247, in CSVFormatter.save(self)
#     243 """
#     244 Create the writer & save.
#     245 """
#     246 # apply compression and byte/text conversion
# --> 247 with get_handle(
#     248     self.filepath_or_buffer,
#     249     self.mode,
#     250     encoding=self.encoding,
#     251     errors=self.errors,
#     252     compression=self.compression,
#     253     storage_options=self.storage_options,
#     254 ) as handles:
#     255     # Note: self.encoding is irrelevant here
#     256     self.writer = csvlib.writer(
#     257         handles.handle,
#     258         lineterminator=self.lineterminator,
#    (...)
#     263         quotechar=self.quotechar,
#     264     )
#     266     self._save()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\JoelTencer\\Documents\\Agilent HPLC 2\\SEC\\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28\\int_results.csv'

# %%
# Add file name and DAD signal

import os
import xlrd
import pandas as pd

def extract_data_from_cells(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Initialize dictionaries to store extracted data
    sample_data = {}
    int_results_data = {}

    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
   # fileinfo1 = wb.sheet_by_name('FileInfo1')
    sample_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26

    # Extract Method from Sheet1 cell B6
    method = sheet1.cell_value(rowx=5, colx=1)  # B6
    
    # Extract Sequence from Sheet1 cell B5
    sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
    sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right

    # Extract file name from Sheet1 cell B33
    file_name_text = sheet1.cell_value(rowx=32, colx=1)  # B33
    file_name = file_name_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):

        # Add a column named 'Sample' with value equal to the sample name
        int_results_data['Sample'] = sample_data['Sample']
        
        # Add a column named 'Peak' with value equal to the current loop number n
        int_results_data['Peak'] = row

        # Add a column named 'Area Perccent' with value equal to the peak's area percent
        # Add the 'Area_Percent' column after 'Peak' column
        
        # Check if column 22 has a value, set area percent accordingly
        try:
            area_percent = int_results_sheet.cell_value(rowx=row, colx=22)
        except IndexError:
            area_percent = ""
        int_results_data['Area_Percent'] = area_percent
        
        sheet_data = {}
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            sheet_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)

        #Make a third data frame for data to add after main data columns
        meta_data = {}
        meta_data['Sequence'] = sequence
        meta_data['Method'] = method
        meta_data['File Name'] = file_name
        
        # Append the row data to the list
        rows_data.append({**int_results_data, **sheet_data, **meta_data})

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    return sample_data, int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                sample_data, int_results_df = extract_data_from_cells(file_path)
                
                # Append the extracted data to the respective lists
                sample_data_list.append(sample_data)
                int_results_df_list.append(int_results_df)

    # Convert the extracted data into dataframes
    sample_df = pd.DataFrame(sample_data_list)
    int_results_df_combined = pd.concat(int_results_df_list)
    
    # Print the extracted dataframes
    print("Sample Dataframe:")
    print(sample_df)
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "int_results.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28
# WARNING *** file size (32454) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32031) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32031) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (36244) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Sample Dataframe:
#      Sample
# 0   770 1A3
# 1   770 1A4
# 2   771 1A6
# 3   771 1A7
# 4   771 1A8
# 5   771 1A9
# 6   772 1A2
# 7   773 1A3
# 8   773 1A4
# 9    ladder
# 10  769 1A5
# 11  769 1A6
#
# IntResults Dataframe:
#     Sample  Peak Area_Percent   RetTime         Area      Height     Width  \
# 0  770 1A3     1        100.0  3.727754   984.238464   60.824165  0.234787
# 0  770 1A4     1               3.728524  1372.649902   83.099113  0.238713
# 0  771 1A6     1               3.737285   630.557251   39.012695  0.232567
# 0  771 1A7     1               3.740605  1003.827087   62.330482  0.231891
# 0  771 1A8     1               3.739514  1133.794067   70.732391  0.231009
# 0  771 1A9     1               3.735433  1190.986572   75.818275  0.225265
# 0  772 1A2     1               3.880362  1505.992920   91.681450  0.235641
# 0  773 1A3     1               3.431879    32.277645    2.137722  0.226156
# 1  773 1A3     2               3.909431  3366.864258  203.777313  0.236760
# 0  773 1A4     1               3.425463    25.783243    1.786172  0.220407
# 1  773 1A4     2               3.903389  3165.020752  196.009232  0.232385
# 0   ladder     1               2.629555   106.284401    6.798275  0.228397
# 1   ladder     2               2.962707   455.443756   25.940151  0.254837
# 2   ladder     3               3.230931   264.975800   16.417297  0.226300
# 3   ladder     4               3.722415  1017.263245   36.858269  0.373992
# 4   ladder     5               4.433238   647.048218   34.472748  0.258982
# 5   ladder     6               5.141259   215.237579    5.513213  0.467470
# 6   ladder     7               5.902357   122.673340    7.320348  0.257508
# 0  769 1A5     1               3.774630   831.223694   48.074066  0.251722
# 0  769 1A6     1               3.766405   984.708984   58.291908  0.243082
#
#    Symmetry   Baseline  TimeStart    LevelStart  BaselineStart   TimeEnd  \
# 0  0.480896   0.244937   3.423667  0.000000e+00       0.217915  5.183667
# 0  0.467937   0.311448   3.431833  0.000000e+00       0.378132  5.305167
# 0  0.450151   0.154830   3.440000 -1.110223e-16       0.226974  5.306667
# 0  0.458167   0.224058   3.449333  0.000000e+00       0.296116  5.309333
# 0  0.457887   0.254438   3.450000  0.000000e+00       0.320435  5.303333
# 0  0.457970   0.193658   3.448333  1.110223e-16       0.265598  5.314697
# 0  0.507016   0.120164   2.869500  0.000000e+00       0.020504  5.336167
# 0  0.964086   0.177019   2.857333  0.000000e+00       0.062466  3.616299
# 1  0.469107   0.272233   3.616299  8.355163e-01       0.213789  5.639555
# 0  0.936864   0.145032   3.019167  0.000000e+00       0.065804  3.608056
# 1  0.465447   0.238227   3.608056  6.647950e-01       0.180637  5.633611
# 0  1.765334  -2.602099   2.212000  0.000000e+00       0.011444  2.730381
# 1  0.867126  -4.687346   2.730381  6.832913e+00      -3.233181  3.166339
# 2  0.294813  -6.366199   3.166339  1.556556e+01      -5.961906  3.471915
# 3  0.476035  -9.442472   3.471915  1.210374e+01      -7.874552  4.215693
# 4  0.930943 -13.891619   4.215693  1.707800e+01     -12.529979  4.725333
# 5  5.577894  -5.279715   4.732000  0.000000e+00     -15.654564  5.330889
# 6  1.150406   0.083779   5.338666  0.000000e+00      -0.467300  6.286445
# 0  0.475215   0.222987   3.479000 -1.110223e-16       0.291824  5.305666
# 0  0.460855   0.201744   3.475833  0.000000e+00       0.270367  5.309166
#
#                                             Sequence            Method  \
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 2  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 3  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 4  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 5  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 6  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
#
#     File Name
# 0  003-0101.D
# 0  003-0101.D
# 0  003-0101.D
# 0  003-0101.D
# 0  003-0101.D
# 0  003-0101.D
# 0  003-0101.D
# 0  003-0101.D
# 1  003-0101.D
# 0  003-0101.D
# 1  003-0101.D
# 0  003-0101.D
# 1  003-0101.D
# 2  003-0101.D
# 3  003-0101.D
# 4  003-0101.D
# 5  003-0101.D
# 6  003-0101.D
# 0  003-0101.D
# 0  003-0101.D
# IntResults DataFrame saved to: C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28\int_results.csv

# %%
# WORKING SCRIPTS!

import os
import xlrd
import pandas as pd

def extract_data_from_cells(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Initialize dictionaries to store extracted data
    sample_data = {}
    int_results_data = {}

    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    sample_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26

    # Extract Method from Sheet1 cell B6
    method = sheet1.cell_value(rowx=5, colx=1)  # B6
    
    # Extract Sequence from Sheet1 cell B5
    sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
    sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right

    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):

        # Add a column named 'Sample' with value equal to the sample name
        int_results_data['Sample'] = sample_data['Sample']
        
        # Add a column named 'Peak' with value equal to the current loop number n
        int_results_data['Peak'] = row

        # Add a column named 'Area Perccent' with value equal to the peak's area percent
        # Add the 'Area_Percent' column after 'Peak' column
        
        # Check if column 22 has a value, set area percent accordingly
        try:
            area_percent = int_results_sheet.cell_value(rowx=row, colx=22)
        except IndexError:
            area_percent = ""
        int_results_data['Area_Percent'] = area_percent
        
        sheet_data = {}
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            sheet_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)

        #Make a third data frame for data to add after main data columns
        meta_data = {}
        meta_data['Sequence'] = sequence
        meta_data['Method'] = method
        
        # Append the row data to the list
        rows_data.append({**int_results_data, **sheet_data, **meta_data})

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    return sample_data, int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                sample_data, int_results_df = extract_data_from_cells(file_path)
                
                # Append the extracted data to the respective lists
                sample_data_list.append(sample_data)
                int_results_df_list.append(int_results_df)

    # Convert the extracted data into dataframes
    sample_df = pd.DataFrame(sample_data_list)
    int_results_df_combined = pd.concat(int_results_df_list)
    
    # Print the extracted dataframes
    print("Sample Dataframe:")
    print(sample_df)
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "int_results.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28
# WARNING *** file size (32454) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32031) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32031) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (36244) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Sample Dataframe:
#      Sample
# 0   770 1A3
# 1   770 1A4
# 2   771 1A6
# 3   771 1A7
# 4   771 1A8
# 5   771 1A9
# 6   772 1A2
# 7   773 1A3
# 8   773 1A4
# 9    ladder
# 10  769 1A5
# 11  769 1A6
#
# IntResults Dataframe:
#     Sample  Peak Area_Percent   RetTime         Area      Height     Width  \
# 0  770 1A3     1        100.0  3.727754   984.238464   60.824165  0.234787
# 0  770 1A4     1               3.728524  1372.649902   83.099113  0.238713
# 0  771 1A6     1               3.737285   630.557251   39.012695  0.232567
# 0  771 1A7     1               3.740605  1003.827087   62.330482  0.231891
# 0  771 1A8     1               3.739514  1133.794067   70.732391  0.231009
# 0  771 1A9     1               3.735433  1190.986572   75.818275  0.225265
# 0  772 1A2     1               3.880362  1505.992920   91.681450  0.235641
# 0  773 1A3     1               3.431879    32.277645    2.137722  0.226156
# 1  773 1A3     2               3.909431  3366.864258  203.777313  0.236760
# 0  773 1A4     1               3.425463    25.783243    1.786172  0.220407
# 1  773 1A4     2               3.903389  3165.020752  196.009232  0.232385
# 0   ladder     1               2.629555   106.284401    6.798275  0.228397
# 1   ladder     2               2.962707   455.443756   25.940151  0.254837
# 2   ladder     3               3.230931   264.975800   16.417297  0.226300
# 3   ladder     4               3.722415  1017.263245   36.858269  0.373992
# 4   ladder     5               4.433238   647.048218   34.472748  0.258982
# 5   ladder     6               5.141259   215.237579    5.513213  0.467470
# 6   ladder     7               5.902357   122.673340    7.320348  0.257508
# 0  769 1A5     1               3.774630   831.223694   48.074066  0.251722
# 0  769 1A6     1               3.766405   984.708984   58.291908  0.243082
#
#    Symmetry   Baseline  TimeStart    LevelStart  BaselineStart   TimeEnd  \
# 0  0.480896   0.244937   3.423667  0.000000e+00       0.217915  5.183667
# 0  0.467937   0.311448   3.431833  0.000000e+00       0.378132  5.305167
# 0  0.450151   0.154830   3.440000 -1.110223e-16       0.226974  5.306667
# 0  0.458167   0.224058   3.449333  0.000000e+00       0.296116  5.309333
# 0  0.457887   0.254438   3.450000  0.000000e+00       0.320435  5.303333
# 0  0.457970   0.193658   3.448333  1.110223e-16       0.265598  5.314697
# 0  0.507016   0.120164   2.869500  0.000000e+00       0.020504  5.336167
# 0  0.964086   0.177019   2.857333  0.000000e+00       0.062466  3.616299
# 1  0.469107   0.272233   3.616299  8.355163e-01       0.213789  5.639555
# 0  0.936864   0.145032   3.019167  0.000000e+00       0.065804  3.608056
# 1  0.465447   0.238227   3.608056  6.647950e-01       0.180637  5.633611
# 0  1.765334  -2.602099   2.212000  0.000000e+00       0.011444  2.730381
# 1  0.867126  -4.687346   2.730381  6.832913e+00      -3.233181  3.166339
# 2  0.294813  -6.366199   3.166339  1.556556e+01      -5.961906  3.471915
# 3  0.476035  -9.442472   3.471915  1.210374e+01      -7.874552  4.215693
# 4  0.930943 -13.891619   4.215693  1.707800e+01     -12.529979  4.725333
# 5  5.577894  -5.279715   4.732000  0.000000e+00     -15.654564  5.330889
# 6  1.150406   0.083779   5.338666  0.000000e+00      -0.467300  6.286445
# 0  0.475215   0.222987   3.479000 -1.110223e-16       0.291824  5.305666
# 0  0.460855   0.201744   3.475833  0.000000e+00       0.270367  5.309166
#
#                                             Sequence            Method
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 2  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 3  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 4  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 5  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 6  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 0  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# IntResults DataFrame saved to: C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28\int_results.csv

# %%
def extract_data_from_cells(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Initialize dictionaries to store extracted data
    sample_data = {}
    int_results_data = {}

    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    sample_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
    
    # Extract Method from Sheet1 cell B6
    method = sheet1.cell_value(rowx=5, colx=1)  # B6
    
    # Extract Sequence from Sheet1 cell B5
    sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
    sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Determine the number of rows and columns in the IntResults sheet
    num_rows = int_results_sheet.nrows
    num_cols = int_results_sheet.ncols
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to the total number of rows
    for row in range(1, num_rows):
        # Check if the row index is within the range of available rows
        if row < num_rows:
            # Add a column named 'Peak' with value equal to the current loop number n
            int_results_data['Sample'] = sample_data['Sample']
            int_results_data['Peak'] = row
            
            # Add the 'Area_Percent' column after 'Peak' column
            if 0 <= 22 < num_cols and int_results_sheet.cell_type(rowx=row, colx=22) != xlrd.XL_CELL_EMPTY:
                area_percent = int_results_sheet.cell_value(rowx=row, colx=22)  # Assuming area percent is in column 22
            else:
                area_percent = ""  # Set area percent to an empty string if it has no value
            int_results_data['Area_Percent'] = area_percent
            
            row_data = {}
            for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
                row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)
            
            # Append the row data to the list
            rows_data.append({**int_results_data, **row_data})

    # Append the 'Sequence' column to the end of the rows_data list
    for row_data in rows_data:
        row_data['Sequence'] = sequence
        
        # Append the 'Method' column to the end of the rows_data list
        row_data['Method'] = method

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    return sample_data, int_results_df
def main():
    # Prompt user to input the parent directory
    parent_directory = input("Paste the parent folder directory path from Windows Explorer: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                sample_data, int_results_df = extract_data_from_cells(file_path)
                
                # Append the extracted data to the respective lists
                sample_data_list.append(sample_data)
                int_results_df_list.append(int_results_df)

    # Convert the extracted data into dataframes
    sample_df = pd.DataFrame(sample_data_list)
    int_results_df_combined = pd.concat(int_results_df_list)
    
    # Print the extracted dataframes
    print("Sample Dataframe:")
    print(sample_df)
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "HPLC_Data_Extract.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Paste the parent folder directory path from Windows Explorer:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28
# WARNING *** file size (32454) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32031) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32031) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (36244) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Sample Dataframe:
#      Sample
# 0   770 1A3
# 1   770 1A4
# 2   771 1A6
# 3   771 1A7
# 4   771 1A8
# 5   771 1A9
# 6   772 1A2
# 7   773 1A3
# 8   773 1A4
# 9    ladder
# 10  769 1A5
# 11  769 1A6
#
# IntResults Dataframe:
#      Sample  Peak Area_Percent   RetTime        Area     Height     Width  \
# 0   770 1A3     1        100.0  3.727754  984.238464  60.824165  0.234787
# 1   770 1A3     2
# 2   770 1A3     3
# 3   770 1A3     4
# 4   770 1A3     5
# ..      ...   ...          ...       ...         ...        ...       ...
# 4   769 1A6     5
# 5   769 1A6     6
# 6   769 1A6     7
# 7   769 1A6     8
# 8   769 1A6     9
#
#     Symmetry  Baseline TimeStart LevelStart BaselineStart   TimeEnd  \
# 0   0.480896  0.244937  3.423667        0.0      0.217915  5.183667
# 1
# 2
# 3
# 4
# ..       ...       ...       ...        ...           ...       ...
# 4
# 5
# 6
# 7
# 8
#
#                                              Sequence            Method
# 0   2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 1   2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 2   2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 3   2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 4   2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# ..                                                ...               ...
# 4   2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 5   2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 6   2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 7   2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 8   2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
#
# [108 rows x 15 columns]
# IntResults DataFrame saved to: C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28\HPLC_Data_Extract.csv

# %%
def extract_data_from_cells(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Initialize dictionaries to store extracted data
    sample_data = {}
    int_results_data = {}

    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    sample_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
    
    # Extract Method from Sheet1 cell B6
    method = sheet1.cell_value(rowx=5, colx=1)  # B6
    
    # Extract Sequence from Sheet1 cell B5
    sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
    sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the number of rows in the IntResults sheet
    num_rows = int_results_sheet.nrows
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to the total number of rows
    for row in range(1, num_rows):
        # Check if the row index is within the range of available rows
        if row < num_rows:
            # Add a column named 'Peak' with value equal to the current loop number n
            int_results_data['Sample'] = sample_data['Sample']
            int_results_data['Peak'] = row
            
            # Add the 'Area_Percent' column after 'Peak' column
            if int_results_sheet.cell_type(rowx=row, colx=22) == xlrd.XL_CELL_EMPTY:
                area_percent = ""
            else:
                area_percent = int_results_sheet.cell_value(rowx=row, colx=22)  # Assuming area percent is in column 22
            int_results_data['Area_Percent'] = area_percent
            
            row_data = {}
            for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
                row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)
            
            # Append the row data to the list
            rows_data.append({**int_results_data, **row_data})

    # Append the 'Sequence' column to the end of the rows_data list
    for row_data in rows_data:
        row_data['Sequence'] = sequence
        
        # Append the 'Method' column to the end of the rows_data list
        row_data['Method'] = method

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    return sample_data, int_results_df
    
def main():
    # Prompt user to input the parent directory
    parent_directory = input("Paste the parent folder directory path from Windows Explorer: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                sample_data, int_results_df = extract_data_from_cells(file_path)
                
                # Append the extracted data to the respective lists
                sample_data_list.append(sample_data)
                int_results_df_list.append(int_results_df)

    # Convert the extracted data into dataframes
    sample_df = pd.DataFrame(sample_data_list)
    int_results_df_combined = pd.concat(int_results_df_list)
    
    # Print the extracted dataframes
    print("Sample Dataframe:")
    print(sample_df)
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "HPLC_Data_Extract.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Paste the parent folder directory path from Windows Explorer:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28\2AG-0901.D
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 100
#      97     print(f"IntResults DataFrame saved to: {int_results_csv_path}")
#      99 if __name__ == "__main__":
# --> 100     main()
#
# Cell In[28], line 78, in main()
#      75 file_path = os.path.join(root, file)
#      77 # Extract data from specific cells
# ---> 78 sample_data, int_results_df = extract_data_from_cells(file_path)
#      80 # Append the extracted data to the respective lists
#      81 sample_data_list.append(sample_data)
#
# Cell In[28], line 38, in extract_data_from_cells(file_path)
#      35 int_results_data['Peak'] = row
#      37 # Add the 'Area_Percent' column after 'Peak' column
# ---> 38 if int_results_sheet.cell_type(rowx=row, colx=22) == xlrd.XL_CELL_EMPTY:
#      39     area_percent = ""
#      40 else:
#
# File ~\anaconda3\Lib\site-packages\xlrd\sheet.py:428, in Sheet.cell_type(self, rowx, colx)
#     422 def cell_type(self, rowx, colx):
#     423     """
#     424     Type of the cell in the given row and column.
#     425
#     426     Refer to the documentation of the :class:`Cell` class.
#     427     """
# --> 428     return self._cell_types[rowx][colx]
#
# IndexError: array index out of range

# %%
#

def extract_data_from_cells(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Initialize dictionaries to store extracted data
    sample_data = {}
    int_results_data = {}

    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    sample_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
    
    # Extract Method from Sheet1 cell B6
    method = sheet1.cell_value(rowx=5, colx=1)  # B6
    
    # Extract Sequence from Sheet1 cell B5
    sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
    sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):

        # Add a column named 'Peak' with value equal to the current loop number n
        int_results_data['Sample'] = sample_data['Sample']
        int_results_data['Peak'] = row
        
        # Add the 'Area_Percent' column after 'Peak' column
        area_percent = int_results_sheet.cell_value(rowx=row, colx=22)  # Assuming area percent is in column 22
        if area_percent == "":
            area_percent = ""  # Set area percent to an empty string if it has no value
        int_results_data['Area_Percent'] = area_percent
        
        row_data = {}
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)
        
        # Append the row data to the list
        rows_data.append({**int_results_data, **row_data})

    # Append the 'Sequence' column to the end of the rows_data list
    for row_data in rows_data:
        row_data['Sequence'] = sequence
        
        # Append the 'Method' column to the end of the rows_data list
        row_data['Method'] = method

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    return sample_data, int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Paste the parent folder directory path from Windows Explorer: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                sample_data, int_results_df = extract_data_from_cells(file_path)
                
                # Append the extracted data to the respective lists
                sample_data_list.append(sample_data)
                int_results_df_list.append(int_results_df)

    # Convert the extracted data into dataframes
    sample_df = pd.DataFrame(sample_data_list)
    int_results_df_combined = pd.concat(int_results_df_list)
    
    # Print the extracted dataframes
    print("Sample Dataframe:")
    print(sample_df)
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "HPLC_Data_Extract.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Paste the parent folder directory path from Windows Explorer:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28
# WARNING *** file size (32454) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 100
#      97     print(f"IntResults DataFrame saved to: {int_results_csv_path}")
#      99 if __name__ == "__main__":
# --> 100     main()
#
# Cell In[25], line 78, in main()
#      75 file_path = os.path.join(root, file)
#      77 # Extract data from specific cells
# ---> 78 sample_data, int_results_df = extract_data_from_cells(file_path)
#      80 # Append the extracted data to the respective lists
#      81 sample_data_list.append(sample_data)
#
# Cell In[25], line 39, in extract_data_from_cells(file_path)
#      36 int_results_data['Peak'] = row
#      38 # Add the 'Area_Percent' column after 'Peak' column
# ---> 39 area_percent = int_results_sheet.cell_value(rowx=row, colx=22)  # Assuming area percent is in column 22
#      40 if area_percent == "":
#      41     area_percent = ""  # Set area percent to an empty string if it has no value
#
# File ~\anaconda3\Lib\site-packages\xlrd\sheet.py:420, in Sheet.cell_value(self, rowx, colx)
#     418 def cell_value(self, rowx, colx):
#     419     "Value of the cell in the given row and column."
# --> 420     return self._cell_values[rowx][colx]
#
# IndexError: list index out of range

# %%
# This is v2, only works with full report #NOT FULL, SHORT OR DETAIL, FILEINFO SHEET WEIRD

def extract_data_from_cells(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Initialize dictionaries to store extracted data
    sample_data = {}
    int_results_data = {}

    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    sample_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
    
    # Extract Method from Sheet1 cell B6
    method = sheet1.cell_value(rowx=5, colx=1)  # B6
    
    # Extract Sequence from Sheet1 cell B5
    sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
    sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):

        # Add a column named 'Peak' with value equal to the current loop number n
        int_results_data['Sample'] = sample_data['Sample']
        int_results_data['Peak'] = row
        
        # Add the 'Area_Percent' column after 'Peak' column
        area_percent = int_results_sheet.cell_value(rowx=row, colx=22)  # Assuming area percent is in column 22
        int_results_data['Area_Percent'] = area_percent
        
        row_data = {}
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)
        
        # Append the row data to the list
        rows_data.append({**int_results_data, **row_data})

    # Append the 'Sequence' column to the end of the rows_data list
    for row_data in rows_data:
        row_data['Sequence'] = sequence
        
        # Append the 'Method' column to the end of the rows_data list
        row_data['Method'] = method

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    return sample_data, int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Paste the parent folder directory path from Windows Explorer: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                sample_data, int_results_df = extract_data_from_cells(file_path)
                
                # Append the extracted data to the respective lists
                sample_data_list.append(sample_data)
                int_results_df_list.append(int_results_df)

    # Convert the extracted data into dataframes
    sample_df = pd.DataFrame(sample_data_list)
    int_results_df_combined = pd.concat(int_results_df_list)
    
    # Print the extracted dataframes
    print("Sample Dataframe:")
    print(sample_df)
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "HPLC_Data_Extract.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Paste the parent folder directory path from Windows Explorer:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28
# WARNING *** file size (32454) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 96
#      93     print(f"IntResults DataFrame saved to: {int_results_csv_path}")
#      95 if __name__ == "__main__":
# ---> 96     main()
#
# Cell In[24], line 74, in main()
#      71 file_path = os.path.join(root, file)
#      73 # Extract data from specific cells
# ---> 74 sample_data, int_results_df = extract_data_from_cells(file_path)
#      76 # Append the extracted data to the respective lists
#      77 sample_data_list.append(sample_data)
#
# Cell In[24], line 37, in extract_data_from_cells(file_path)
#      34 int_results_data['Peak'] = row
#      36 # Add the 'Area_Percent' column after 'Peak' column
# ---> 37 area_percent = int_results_sheet.cell_value(rowx=row, colx=22)  # Assuming area percent is in column 22
#      38 int_results_data['Area_Percent'] = area_percent
#      40 row_data = {}
#
# File ~\anaconda3\Lib\site-packages\xlrd\sheet.py:420, in Sheet.cell_value(self, rowx, colx)
#     418 def cell_value(self, rowx, colx):
#     419     "Value of the cell in the given row and column."
# --> 420     return self._cell_values[rowx][colx]
#
# IndexError: list index out of range

# %%
def extract_data_from_cells(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Initialize dictionaries to store extracted data
    sample_data = {}
    int_results_data = {}

    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    sample_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
    
    # Extract Method from Sheet1 cell B6
    method = sheet1.cell_value(rowx=5, colx=1)  # B6
    
    # Extract Sequence from Sheet1 cell B5
    sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
    sequence = sequence_text.rsplit("\\", 2)[-2]  # Extract text between two backslashes starting from the right
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):

        # Add a column named 'Peak' with value equal to the current loop number n
        int_results_data['Sample'] = sample_data['Sample']
        int_results_data['Peak'] = row
        
        # Add the 'Area_Percent' column after 'Peak' column
        area_percent = int_results_sheet.cell_value(rowx=row, colx=22)  # Assuming area percent is in column 22
        int_results_data['Area_Percent'] = area_percent
        
        row_data = {}
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)
        
        # Append the row data to the list
        rows_data.append({**int_results_data, **row_data})

        # Append the 'Sequence' column to the end of the rows_data list
        int_results_data['Sequence'] = sequence
        
        # Append the 'Method' column to the end of the rows_data list
        int_results_data['Method'] = method

        # Create DataFrame from the list of row data
        int_results_df = pd.DataFrame(rows_data)

    return sample_data, int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Paste the parent folder directory path from Windows Explorer: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                sample_data, int_results_df = extract_data_from_cells(file_path)
                
                # Append the extracted data to the respective lists
                sample_data_list.append(sample_data)
                int_results_df_list.append(int_results_df)

    # Convert the extracted data into dataframes
    sample_df = pd.DataFrame(sample_data_list)
    int_results_df_combined = pd.concat(int_results_df_list)
    
    # Print the extracted dataframes
    print("Sample Dataframe:")
    print(sample_df)
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "HPLC_Data_Extract.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Paste the parent folder directory path from Windows Explorer:  C:\Users\JoelTencer\Documents\HPLC\full report
# WARNING *** file size (38961) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Sample Dataframe:
#     Sample
# 0  770 1A3
#
# IntResults Dataframe:
#     Sample  Peak  Area_Percent   RetTime         Area     Height     Width  \
# 0  770 1A3     1      0.427019  2.533667     4.396246   0.280334  0.234959
# 1  770 1A3     2      0.604369  3.266259     6.222103   0.374421  0.231876
# 2  770 1A3     3     97.946593  3.727843  1008.380127  61.024811  0.238781
# 3  770 1A3     4      0.225631  5.240099     2.322921   0.355774  0.092174
# 4  770 1A3     5      0.372004  5.423666     3.829855   0.377986  0.148210
# 5  770 1A3     6      0.186258  5.902758     1.917563   0.146571  0.164633
# 6  770 1A3     7      0.238126  6.039222     2.451552   0.155675  0.219726
#
#    Symmetry  Baseline  TimeStart  LevelStart  BaselineStart   TimeEnd  \
# 0  0.571415 -0.010205   2.277000    0.000000      -0.021458  2.873667
# 1  1.322650  0.021912   2.873667    0.061341       0.004701  3.425889
# 2  0.470640  0.042148   3.425889    0.189322       0.028910  5.184519
# 3  0.782442  0.108446   5.184519    0.268552       0.106010  5.319222
# 4  0.926128  0.116494   5.319222    0.203433       0.111915  5.627000
# 5  2.368346  0.111887   5.627000    0.000000       0.125408  5.974333
# 6  0.273263  0.105195   5.974333    0.132617       0.108377  6.803667
#
#                                             Sequence            Method
# 0                                                NaN               NaN
# 1  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 2  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 3  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 4  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 5  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# 6  2024 04 18 770 771 772 773 ELUTIONS 2024-04-18...  LHN SEC2 150MM.M
# IntResults DataFrame saved to: C:\Users\JoelTencer\Documents\HPLC\full report\HPLC_Data_Extract.csv

# %%
def extract_data_from_cells(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Initialize dictionaries to store extracted data
    sample_data = {}
    int_results_data = {}

    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    sample_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
    
    # Extract Sequence from Sheet1 cell B5
    sequence_text = sheet1.cell_value(rowx=4, colx=1)  # B5
    sequence = sequence_text.split("\\")[1]  # Extract text between two backslashes
    int_results_data['Sequence'] = sequence
    
    # Extract Method from Sheet1 cell B6
    method = sheet1.cell_value(rowx=5, colx=1)  # B6
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):

        # Add a column named 'Peak' with value equal to the current loop number n
        int_results_data['Sample'] = sample_data['Sample']
        int_results_data['Peak'] = row
        
        # Add the 'Area_Percent' column after 'Peak' column
        area_percent = int_results_sheet.cell_value(rowx=row, colx=22)  # Assuming area percent is in column 22
        int_results_data['Area_Percent'] = area_percent
        
        row_data = {}
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)
        
        # Append the row data to the list
        rows_data.append({**int_results_data, **row_data})

    # Append the 'Method' column to the end of the rows_data list
    for row in rows_data:
        row['Method'] = method

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    return sample_data, int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Paste the parent folder directory path from Windows Explorer: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                sample_data, int_results_df = extract_data_from_cells(file_path)
                
                # Append the extracted data to the respective lists
                sample_data_list.append(sample_data)
                int_results_df_list.append(int_results_df)

    # Convert the extracted data into dataframes
    sample_df = pd.DataFrame(sample_data_list)
    int_results_df_combined = pd.concat(int_results_df_list)
    
    # Print the extracted dataframes
    print("Sample Dataframe:")
    print(sample_df)
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "int_results.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Paste the parent folder directory path from Windows Explorer:  C:\Users\JoelTencer\Documents\HPLC\full report
# WARNING *** file size (38961) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Sample Dataframe:
#     Sample
# 0  770 1A3
#
# IntResults Dataframe:
#   Sequence   Sample  Peak  Area_Percent   RetTime         Area     Height  \
# 0   Chem32  770 1A3     1      0.427019  2.533667     4.396246   0.280334
# 1   Chem32  770 1A3     2      0.604369  3.266259     6.222103   0.374421
# 2   Chem32  770 1A3     3     97.946593  3.727843  1008.380127  61.024811
# 3   Chem32  770 1A3     4      0.225631  5.240099     2.322921   0.355774
# 4   Chem32  770 1A3     5      0.372004  5.423666     3.829855   0.377986
# 5   Chem32  770 1A3     6      0.186258  5.902758     1.917563   0.146571
# 6   Chem32  770 1A3     7      0.238126  6.039222     2.451552   0.155675
#
#       Width  Symmetry  Baseline  TimeStart  LevelStart  BaselineStart  \
# 0  0.234959  0.571415 -0.010205   2.277000    0.000000      -0.021458
# 1  0.231876  1.322650  0.021912   2.873667    0.061341       0.004701
# 2  0.238781  0.470640  0.042148   3.425889    0.189322       0.028910
# 3  0.092174  0.782442  0.108446   5.184519    0.268552       0.106010
# 4  0.148210  0.926128  0.116494   5.319222    0.203433       0.111915
# 5  0.164633  2.368346  0.111887   5.627000    0.000000       0.125408
# 6  0.219726  0.273263  0.105195   5.974333    0.132617       0.108377
#
#     TimeEnd            Method
# 0  2.873667  LHN SEC2 150MM.M
# 1  3.425889  LHN SEC2 150MM.M
# 2  5.184519  LHN SEC2 150MM.M
# 3  5.319222  LHN SEC2 150MM.M
# 4  5.627000  LHN SEC2 150MM.M
# 5  5.974333  LHN SEC2 150MM.M
# 6  6.803667  LHN SEC2 150MM.M
# IntResults DataFrame saved to: C:\Users\JoelTencer\Documents\HPLC\full report\int_results.csv

# %%
def extract_data_from_cells(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Initialize dictionaries to store extracted data
    sample_data = {}
    int_results_data = {}

    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    sample_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
    
    # Extract Method from Sheet1 cell B6
    method = sheet1.cell_value(rowx=5, colx=1)  # B6
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):

        # Add a column named 'Peak' with value equal to the current loop number n
        int_results_data['Sample'] = sample_data['Sample']
        int_results_data['Peak'] = row
        
        # Add the 'Area_Percent' column after 'Peak' column
        area_percent = int_results_sheet.cell_value(rowx=row, colx=22)  # Assuming area percent is in column 22
        int_results_data['Area_Percent'] = area_percent
        
        row_data = {}
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)
        
        # Append the row data to the list
        rows_data.append({**int_results_data, **row_data})
    
    # Append the 'Method' column to the end of the rows_data list
    for row in rows_data:
        row['Method'] = method

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    return sample_data, int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Paste the parent folder directory path from Windows Explorer: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                sample_data, int_results_df = extract_data_from_cells(file_path)
                
                # Append the extracted data to the respective lists
                sample_data_list.append(sample_data)
                int_results_df_list.append(int_results_df)

    # Convert the extracted data into dataframes
    sample_df = pd.DataFrame(sample_data_list)
    int_results_df_combined = pd.concat(int_results_df_list)
    
    # Print the extracted dataframes
    print("Sample Dataframe:")
    print(sample_df)
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "int_results.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Paste the parent folder directory path from Windows Explorer:  C:\Users\JoelTencer\Documents\HPLC\full report
# WARNING *** file size (38961) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Sample Dataframe:
#     Sample
# 0  770 1A3
#
# IntResults Dataframe:
#     Sample  Peak  Area_Percent   RetTime         Area     Height     Width  \
# 0  770 1A3     1      0.427019  2.533667     4.396246   0.280334  0.234959
# 1  770 1A3     2      0.604369  3.266259     6.222103   0.374421  0.231876
# 2  770 1A3     3     97.946593  3.727843  1008.380127  61.024811  0.238781
# 3  770 1A3     4      0.225631  5.240099     2.322921   0.355774  0.092174
# 4  770 1A3     5      0.372004  5.423666     3.829855   0.377986  0.148210
# 5  770 1A3     6      0.186258  5.902758     1.917563   0.146571  0.164633
# 6  770 1A3     7      0.238126  6.039222     2.451552   0.155675  0.219726
#
#    Symmetry  Baseline  TimeStart  LevelStart  BaselineStart   TimeEnd  \
# 0  0.571415 -0.010205   2.277000    0.000000      -0.021458  2.873667
# 1  1.322650  0.021912   2.873667    0.061341       0.004701  3.425889
# 2  0.470640  0.042148   3.425889    0.189322       0.028910  5.184519
# 3  0.782442  0.108446   5.184519    0.268552       0.106010  5.319222
# 4  0.926128  0.116494   5.319222    0.203433       0.111915  5.627000
# 5  2.368346  0.111887   5.627000    0.000000       0.125408  5.974333
# 6  0.273263  0.105195   5.974333    0.132617       0.108377  6.803667
#
#              Method
# 0  LHN SEC2 150MM.M
# 1  LHN SEC2 150MM.M
# 2  LHN SEC2 150MM.M
# 3  LHN SEC2 150MM.M
# 4  LHN SEC2 150MM.M
# 5  LHN SEC2 150MM.M
# 6  LHN SEC2 150MM.M
# IntResults DataFrame saved to: C:\Users\JoelTencer\Documents\HPLC\full report\int_results.csv

# %%
## add area percent from full report xls file

import os
import xlrd
import pandas as pd

def extract_data_from_cells(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Initialize dictionaries to store extracted data
    sample_data = {}
    int_results_data = {}

    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    sample_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):

        
        
        # Add a column named 'Peak' with value equal to the current loop number n
        int_results_data['Sample'] = sample_data['Sample']
        int_results_data['Peak'] = row
        
        # Add the 'Area_Percent' column after 'Peak' column
        area_percent = int_results_sheet.cell_value(rowx=row, colx=22)  # Assuming area percent is in column 22
        int_results_data['Area_Percent'] = area_percent
        
        row_data = {}
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)
        
        # Append the row data to the list
        rows_data.append({**int_results_data, **row_data})

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    return sample_data, int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Paste the parent folder directory path from Windows Explorer: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                sample_data, int_results_df = extract_data_from_cells(file_path)
                
                # Append the extracted data to the respective lists
                sample_data_list.append(sample_data)
                int_results_df_list.append(int_results_df)

    # Convert the extracted data into dataframes
    sample_df = pd.DataFrame(sample_data_list)
    int_results_df_combined = pd.concat(int_results_df_list)
    
    # Print the extracted dataframes
    print("Sample Dataframe:")
    print(sample_df)
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "int_results.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Paste the parent folder directory path from Windows Explorer:  C:\Users\JoelTencer\Documents\HPLC\full report
# WARNING *** file size (38961) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Sample Dataframe:
#     Sample
# 0  770 1A3
#
# IntResults Dataframe:
#     Sample  Peak  Area_Percent   RetTime         Area     Height     Width  \
# 0  770 1A3     1      0.427019  2.533667     4.396246   0.280334  0.234959
# 1  770 1A3     2      0.604369  3.266259     6.222103   0.374421  0.231876
# 2  770 1A3     3     97.946593  3.727843  1008.380127  61.024811  0.238781
# 3  770 1A3     4      0.225631  5.240099     2.322921   0.355774  0.092174
# 4  770 1A3     5      0.372004  5.423666     3.829855   0.377986  0.148210
# 5  770 1A3     6      0.186258  5.902758     1.917563   0.146571  0.164633
# 6  770 1A3     7      0.238126  6.039222     2.451552   0.155675  0.219726
#
#    Symmetry  Baseline  TimeStart  LevelStart  BaselineStart   TimeEnd
# 0  0.571415 -0.010205   2.277000    0.000000      -0.021458  2.873667
# 1  1.322650  0.021912   2.873667    0.061341       0.004701  3.425889
# 2  0.470640  0.042148   3.425889    0.189322       0.028910  5.184519
# 3  0.782442  0.108446   5.184519    0.268552       0.106010  5.319222
# 4  0.926128  0.116494   5.319222    0.203433       0.111915  5.627000
# 5  2.368346  0.111887   5.627000    0.000000       0.125408  5.974333
# 6  0.273263  0.105195   5.974333    0.132617       0.108377  6.803667
# IntResults DataFrame saved to: C:\Users\JoelTencer\Documents\HPLC\full report\int_results.csv

# %%
# WORKING SCRIPTS!

import os
import xlrd
import pandas as pd

def extract_data_from_cells(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Initialize dictionaries to store extracted data
    sample_data = {}
    int_results_data = {}

    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    sample_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 1 up to row n
    for row in range(1, n + 1):
        # Add a column named 'Peak' with value equal to the current loop number n
        int_results_data['Sample'] = sample_data['Sample']
        int_results_data['Peak'] = row
        
        row_data = {}
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)
        # Append the row data to the list
        rows_data.append({**int_results_data, **row_data})

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    return sample_data, int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Recursively search for .xls files in the parent directory and its subdirectories
    for root, dirs, files in os.walk(parent_directory):
        for file in files:
            if file.endswith(".xls"):
                file_path = os.path.join(root, file)
                
                # Extract data from specific cells
                sample_data, int_results_df = extract_data_from_cells(file_path)
                
                # Append the extracted data to the respective lists
                sample_data_list.append(sample_data)
                int_results_df_list.append(int_results_df)

    # Convert the extracted data into dataframes
    sample_df = pd.DataFrame(sample_data_list)
    int_results_df_combined = pd.concat(int_results_df_list)
    
    # Print the extracted dataframes
    print("Sample Dataframe:")
    print(sample_df)
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "int_results.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28
# WARNING *** file size (32454) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32401) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32031) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (32031) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (36244) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Sample Dataframe:
#      Sample
# 0   770 1A3
# 1   770 1A4
# 2   771 1A6
# 3   771 1A7
# 4   771 1A8
# 5   771 1A9
# 6   772 1A2
# 7   773 1A3
# 8   773 1A4
# 9    ladder
# 10  769 1A5
# 11  769 1A6
#
# IntResults Dataframe:
#     Sample  Peak   RetTime         Area      Height     Width  Symmetry  \
# 0  770 1A3     1  3.727754   984.238464   60.824165  0.234787  0.480896
# 0  770 1A4     1  3.728524  1372.649902   83.099113  0.238713  0.467937
# 0  771 1A6     1  3.737285   630.557251   39.012695  0.232567  0.450151
# 0  771 1A7     1  3.740605  1003.827087   62.330482  0.231891  0.458167
# 0  771 1A8     1  3.739514  1133.794067   70.732391  0.231009  0.457887
# 0  771 1A9     1  3.735433  1190.986572   75.818275  0.225265  0.457970
# 0  772 1A2     1  3.880362  1505.992920   91.681450  0.235641  0.507016
# 0  773 1A3     1  3.431879    32.277645    2.137722  0.226156  0.964086
# 1  773 1A3     2  3.909431  3366.864258  203.777313  0.236760  0.469107
# 0  773 1A4     1  3.425463    25.783243    1.786172  0.220407  0.936864
# 1  773 1A4     2  3.903389  3165.020752  196.009232  0.232385  0.465447
# 0   ladder     1  2.629555   106.284401    6.798275  0.228397  1.765334
# 1   ladder     2  2.962707   455.443756   25.940151  0.254837  0.867126
# 2   ladder     3  3.230931   264.975800   16.417297  0.226300  0.294813
# 3   ladder     4  3.722415  1017.263245   36.858269  0.373992  0.476035
# 4   ladder     5  4.433238   647.048218   34.472748  0.258982  0.930943
# 5   ladder     6  5.141259   215.237579    5.513213  0.467470  5.577894
# 6   ladder     7  5.902357   122.673340    7.320348  0.257508  1.150406
# 0  769 1A5     1  3.774630   831.223694   48.074066  0.251722  0.475215
# 0  769 1A6     1  3.766405   984.708984   58.291908  0.243082  0.460855
#
#     Baseline  TimeStart    LevelStart  BaselineStart   TimeEnd
# 0   0.244937   3.423667  0.000000e+00       0.217915  5.183667
# 0   0.311448   3.431833  0.000000e+00       0.378132  5.305167
# 0   0.154830   3.440000 -1.110223e-16       0.226974  5.306667
# 0   0.224058   3.449333  0.000000e+00       0.296116  5.309333
# 0   0.254438   3.450000  0.000000e+00       0.320435  5.303333
# 0   0.193658   3.448333  1.110223e-16       0.265598  5.314697
# 0   0.120164   2.869500  0.000000e+00       0.020504  5.336167
# 0   0.177019   2.857333  0.000000e+00       0.062466  3.616299
# 1   0.272233   3.616299  8.355163e-01       0.213789  5.639555
# 0   0.145032   3.019167  0.000000e+00       0.065804  3.608056
# 1   0.238227   3.608056  6.647950e-01       0.180637  5.633611
# 0  -2.602099   2.212000  0.000000e+00       0.011444  2.730381
# 1  -4.687346   2.730381  6.832913e+00      -3.233181  3.166339
# 2  -6.366199   3.166339  1.556556e+01      -5.961906  3.471915
# 3  -9.442472   3.471915  1.210374e+01      -7.874552  4.215693
# 4 -13.891619   4.215693  1.707800e+01     -12.529979  4.725333
# 5  -5.279715   4.732000  0.000000e+00     -15.654564  5.330889
# 6   0.083779   5.338666  0.000000e+00      -0.467300  6.286445
# 0   0.222987   3.479000 -1.110223e-16       0.291824  5.305666
# 0   0.201744   3.475833  0.000000e+00       0.270367  5.309166
# IntResults DataFrame saved to: C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28\int_results.csv

# %%
import os
import xlrd
import pandas as pd

def extract_data_from_cells(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Initialize dictionaries to store extracted data
    sample_data = {}
    int_results_data = {}

    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    sample_data['Sample'] = sheet1.cell_value(rowx=25, colx=1)  # B26
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 2 up to row 2 + n
    for row in range(1, 1 + n):
        # Add a column named 'Peak' with value equal to the current loop number n
        int_results_data['Sample'] = sample_data['Sample']
        int_results_data['Peak'] = row
        
        row_data = {}
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)
        # Append the row data to the list
        rows_data.append({**int_results_data, **row_data})

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    return sample_data, int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Loop through each file in the directory
    for filename in os.listdir(parent_directory):
        # Check if the file ends with ".xls"
        if filename.endswith(".xls"):
            file_path = os.path.join(parent_directory, filename)
            
            # Extract data from specific cells
            sample_data, int_results_df = extract_data_from_cells(file_path)
            
            # Append the extracted data to the respective lists
            sample_data_list.append(sample_data)
            int_results_df_list.append(int_results_df)

    # Convert the extracted data into dataframes
    sample_df = pd.DataFrame(sample_data_list)
    int_results_df_combined = pd.concat(int_results_df_list)
    
    # Print the extracted dataframes
    print("Sample Dataframe:")
    print(sample_df)
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "int_results.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 80
#      77     print(f"IntResults DataFrame saved to: {int_results_csv_path}")
#      79 if __name__ == "__main__":
# ---> 80     main()
#
# Cell In[47], line 66, in main()
#      64 # Convert the extracted data into dataframes
#      65 sample_df = pd.DataFrame(sample_data_list)
# ---> 66 int_results_df_combined = pd.concat(int_results_df_list)
#      68 # Print the extracted dataframes
#      69 print("Sample Dataframe:")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:380, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     377 elif copy and using_copy_on_write():
#     378     copy = False
# --> 380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#     383     ignore_index=ignore_index,
#     384     join=join,
#     385     keys=keys,
#     386     levels=levels,
#     387     names=names,
#     388     verify_integrity=verify_integrity,
#     389     copy=copy,
#     390     sort=sort,
#     391 )
#     393 return op.get_result()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:443, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     440 self.verify_integrity = verify_integrity
#     441 self.copy = copy
# --> 443 objs, keys = self._clean_keys_and_objs(objs, keys)
#     445 # figure out what our result ndim is going to be
#     446 ndims = self._get_ndims(objs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:505, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     502     objs_list = list(objs)
#     504 if len(objs_list) == 0:
# --> 505     raise ValueError("No objects to concatenate")
#     507 if keys is None:
#     508     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
import os
import xlrd
import pandas as pd

def extract_data_from_cells(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Initialize dictionaries to store extracted data
    sample_data = {}
    int_results_data = {}

    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    sample_data['SampleName'] = sheet1.cell_value(rowx=25, colx=1)  # B26
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 2 up to row 2 + n
    for row in range(1, 1 + n):
        # Add a column named 'Peak' with value equal to the current loop number n
        int_results_data['Peak'] = row - 1
        
        row_data = {}
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)
        # Append the row data to the list
        rows_data.append({**int_results_data, **row_data})

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    return sample_data, int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Loop through each file in the directory
    for filename in os.listdir(parent_directory):
        # Check if the file ends with ".xls"
        if filename.endswith(".xls"):
            file_path = os.path.join(parent_directory, filename)
            
            # Extract data from specific cells
            sample_data, int_results_df = extract_data_from_cells(file_path)
            
            # Append the extracted data to the respective lists
            sample_data_list.append(sample_data)
            int_results_df_list.append(int_results_df)

    # Convert the extracted data into dataframes
    sample_df = pd.DataFrame(sample_data_list)
    int_results_df_combined = pd.concat(int_results_df_list)
    
    # Print the extracted dataframes
    print("Sample Dataframe:")
    print(sample_df)
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "int_results.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28\2AJ-1401.D
# WARNING *** file size (36244) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Sample Dataframe:
#   SampleName
# 0     ladder
#
# IntResults Dataframe:
#    Peak   RetTime         Area     Height     Width  Symmetry   Baseline  \
# 0     0  2.629555   106.284401   6.798275  0.228397  1.765334  -2.602099
# 1     1  2.962707   455.443756  25.940151  0.254837  0.867126  -4.687346
# 2     2  3.230931   264.975800  16.417297  0.226300  0.294813  -6.366199
# 3     3  3.722415  1017.263245  36.858269  0.373992  0.476035  -9.442472
# 4     4  4.433238   647.048218  34.472748  0.258982  0.930943 -13.891619
# 5     5  5.141259   215.237579   5.513213  0.467470  5.577894  -5.279715
# 6     6  5.902357   122.673340   7.320348  0.257508  1.150406   0.083779
#
#    TimeStart  LevelStart  BaselineStart   TimeEnd
# 0   2.212000    0.000000       0.011444  2.730381
# 1   2.730381    6.832913      -3.233181  3.166339
# 2   3.166339   15.565557      -5.961906  3.471915
# 3   3.471915   12.103737      -7.874552  4.215693
# 4   4.215693   17.077999     -12.529979  4.725333
# 5   4.732000    0.000000     -15.654564  5.330889
# 6   5.338666    0.000000      -0.467300  6.286445
# IntResults DataFrame saved to: C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28\2AJ-1401.D\int_results.csv

# %%
import os
import xlrd
import pandas as pd

def extract_data_from_cells(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Initialize dictionaries to store extracted data
    sample_data = {}
    int_results_data = {}

    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    sample_data['SampleName'] = sheet1.cell_value(rowx=25, colx=1)  # B26
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 2 up to row 2 + n
    for row in range(2, 2 + n + 1):
        # Add a column named 'Peak' with value equal to the current loop number n
        int_results_data['Peak'] = [row - 1]
        
        row_data = {}
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)
        # Append the row data to the list
        rows_data.append({**int_results_data, **row_data})

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    return sample_data, int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Loop through each file in the directory
    for filename in os.listdir(parent_directory):
        # Check if the file ends with ".xls"
        if filename.endswith(".xls"):
            file_path = os.path.join(parent_directory, filename)
            
            # Extract data from specific cells
            sample_data, int_results_df = extract_data_from_cells(file_path)
            
            # Append the extracted data to the respective lists
            sample_data_list.append(sample_data)
            int_results_df_list.append(int_results_df)

    # Convert the extracted data into dataframes
    sample_df = pd.DataFrame(sample_data_list)
    int_results_df_combined = pd.concat(int_results_df_list)
    
    # Print the extracted dataframes
    print("Sample Dataframe:")
    print(sample_df)
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "int_results.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28\2AJ-1401.D
# WARNING *** file size (36244) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Sample Dataframe:
#   SampleName
# 0     ladder
#
# IntResults Dataframe:
#   Peak   RetTime         Area     Height     Width  Symmetry   Baseline  \
# 0  [1]  2.962707   455.443756  25.940151  0.254837  0.867126  -4.687346
# 1  [2]  3.230931     264.9758  16.417297    0.2263  0.294813  -6.366199
# 2  [3]  3.722415  1017.263245  36.858269  0.373992  0.476035  -9.442472
# 3  [4]  4.433238   647.048218  34.472748  0.258982  0.930943 -13.891619
# 4  [5]  5.141259   215.237579   5.513213   0.46747  5.577894  -5.279715
# 5  [6]  5.902357    122.67334   7.320348  0.257508  1.150406   0.083779
# 6  [7]
# 7  [8]
#
#   TimeStart LevelStart BaselineStart   TimeEnd
# 0  2.730381   6.832913     -3.233181  3.166339
# 1  3.166339  15.565557     -5.961906  3.471915
# 2  3.471915  12.103737     -7.874552  4.215693
# 3  4.215693  17.077999    -12.529979  4.725333
# 4     4.732        0.0    -15.654564  5.330889
# 5  5.338666        0.0       -0.4673  6.286445
# 6
# 7
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[35], line 79
#      76     print(f"IntResults DataFrame saved to: {int_results_csv_path}")
#      78 if __name__ == "__main__":
# ---> 79     main()
#
# Cell In[35], line 75, in main()
#      73 # Save IntResults DataFrame to CSV
#      74 int_results_csv_path = os.path.join(parent_directory, "int_results.csv")
# ---> 75 int_results_df_combined.to_csv(int_results_csv_path, index=False)
#      76 print(f"IntResults DataFrame saved to: {int_results_csv_path}")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
#    3906     encoding=encoding,
#    3907     errors=errors,
#    3908     compression=compression,
#    3909     quoting=quoting,
#    3910     columns=columns,
#    3911     index_label=index_label,
#    3912     mode=mode,
#    3913     chunksize=chunksize,
#    3914     quotechar=quotechar,
#    3915     date_format=date_format,
#    3916     doublequote=doublequote,
#    3917     escapechar=escapechar,
#    3918     storage_options=storage_options,
#    3919 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1152, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1131     created_buffer = False
#    1133 csv_formatter = CSVFormatter(
#    1134     path_or_buf=path_or_buf,
#    1135     lineterminator=lineterminator,
#    (...)
#    1150     formatter=self.fmt,
#    1151 )
# -> 1152 csv_formatter.save()
#    1154 if created_buffer:
#    1155     assert isinstance(path_or_buf, StringIO)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:247, in CSVFormatter.save(self)
#     243 """
#     244 Create the writer & save.
#     245 """
#     246 # apply compression and byte/text conversion
# --> 247 with get_handle(
#     248     self.filepath_or_buffer,
#     249     self.mode,
#     250     encoding=self.encoding,
#     251     errors=self.errors,
#     252     compression=self.compression,
#     253     storage_options=self.storage_options,
#     254 ) as handles:
#     255     # Note: self.encoding is irrelevant here
#     256     self.writer = csvlib.writer(
#     257         handles.handle,
#     258         lineterminator=self.lineterminator,
#    (...)
#     263         quotechar=self.quotechar,
#     264     )
#     266     self._save()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\JoelTencer\\Documents\\Agilent HPLC 2\\SEC\\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28\\2AJ-1401.D\\int_results.csv'

# %%
import os
import xlrd
import pandas as pd

def extract_data_from_cells(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Initialize dictionaries to store extracted data
    sample_data = {}
    int_results_data = {}

    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    sample_data['SampleName'] = sheet1.cell_value(rowx=25, colx=1)  # B26
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Initialize an empty list to store row data
    rows_data = []
    
    # Loop through cells for each value starting from row 2 up to row 2 + n
    for row in range(2, 2 + n):
        # Add a column named 'Peak' with value equal to the current loop number n
        int_results_data['Peak'] = [row -1]
        
        row_data = {}
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)
        # Append the row data to the list
        rows_data.append({**int_results_data, **row_data})

    # Create DataFrame from the list of row data
    int_results_df = pd.DataFrame(rows_data)

    return sample_data, int_results_df

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_df_list = []

    # Loop through each file in the directory
    for filename in os.listdir(parent_directory):
        # Check if the file ends with ".xls"
        if filename.endswith(".xls"):
            file_path = os.path.join(parent_directory, filename)
            
            # Extract data from specific cells
            sample_data, int_results_df = extract_data_from_cells(file_path)
            
            # Append the extracted data to the respective lists
            sample_data_list.append(sample_data)
            int_results_df_list.append(int_results_df)

    # Convert the extracted data into dataframes
    sample_df = pd.DataFrame(sample_data_list)
    int_results_df_combined = pd.concat(int_results_df_list)
    
    # Print the extracted dataframes
    print("Sample Dataframe:")
    print(sample_df)
    print("\nIntResults Dataframe:")
    print(int_results_df_combined)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "int_results.csv")
    int_results_df_combined.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path:  import os import xlrd import pandas as pd  def extract_data_from_cells(file_path):     # Open the Excel file     wb = xlrd.open_workbook(file_path)          # Initialize dictionaries to store extracted data     sample_data = {}     int_results_data = {}      # Extract data from Sheet1 (SampleName)     sheet1 = wb.sheet_by_name('Sheet1')     sample_data['SampleName'] = sheet1.cell_value(rowx=25, colx=1)  # B26          # Extract data from IntResults sheet     int_results_sheet = wb.sheet_by_name('IntResults1')          # Check the value of cell B2     n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n          # Initialize an empty list to store row data     rows_data = []          # Loop through cells for each value starting from row 2 up to row 2 + n     for row in range(2, 2 + n):         # Add a column named 'Peak' with value equal to the current loop number n         int_results_data['Peak'] = [row -1]                  row_data = {}         for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):             row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)         # Append the row data to the list         rows_data.append({**int_results_data, **row_data})      # Create DataFrame from the list of row data     int_results_df = pd.DataFrame(rows_data)      return sample_data, int_results_df  def main():     # Prompt user to input the parent directory     parent_directory = input("Enter the parent directory path: ")      # Initialize lists to store extracted data     sample_data_list = []     int_results_df_list = []      # Loop through each file in the directory     for filename in os.listdir(parent_directory):         # Check if the file ends with ".xls"         if filename.endswith(".xls"):             file_path = os.path.join(parent_directory, filename)                          # Extract data from specific cells             sample_data, int_results_df = extract_data_from_cells(file_path)                          # Append the extracted data to the respective lists             sample_data_list.append(sample_data)             int_results_df_list.append(int_results_df)      # Convert the extracted data into dataframes     sample_df = pd.DataFrame(sample_data_list)     int_results_df_combined = pd.concat(int_results_df_list)          # Print the extracted dataframes     print("Sample Dataframe:")     print(sample_df)     print("\nIntResults Dataframe:")     print(int_results_df_combined)          # Save IntResults DataFrame to CSV     int_results_csv_path = os.path.join(parent_directory, "int_results.csv")     int_results_df_combined.to_csv(int_results_csv_path, index=False)     print(f"IntResults DataFrame saved to: {int_results_csv_path}")  if __name__ == "__main__":     main()
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 79
#      76     print(f"IntResults DataFrame saved to: {int_results_csv_path}")
#      78 if __name__ == "__main__":
# ---> 79     main()
#
# Cell In[33], line 51, in main()
#      48 int_results_df_list = []
#      50 # Loop through each file in the directory
# ---> 51 for filename in os.listdir(parent_directory):
#      52     # Check if the file ends with ".xls"
#      53     if filename.endswith(".xls"):
#      54         file_path = os.path.join(parent_directory, filename)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'import os import xlrd import pandas as pd  def extract_data_from_cells(file_path):     # Open the Excel file     wb = xlrd.open_workbook(file_path)          # Initialize dictionaries to store extracted data     sample_data = {}     int_results_data = {}      # Extract data from Sheet1 (SampleName)     sheet1 = wb.sheet_by_name(\'Sheet1\')     sample_data[\'SampleName\'] = sheet1.cell_value(rowx=25, colx=1)  # B26          # Extract data from IntResults sheet     int_results_sheet = wb.sheet_by_name(\'IntResults1\')          # Check the value of cell B2     n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n          # Initialize an empty list to store row data     rows_data = []          # Loop through cells for each value starting from row 2 up to row 2 + n     for row in range(2, 2 + n):         # Add a column named \'Peak\' with value equal to the current loop number n         int_results_data[\'Peak\'] = [row -1]                  row_data = {}         for col, label in zip(range(4, 14), [\'RetTime\', \'Area\', \'Height\', \'Width\', \'Symmetry\', \'Baseline\', \'TimeStart\', \'LevelStart\', \'BaselineStart\', \'TimeEnd\']):             row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)         # Append the row data to the list         rows_data.append({**int_results_data, **row_data})      # Create DataFrame from the list of row data     int_results_df = pd.DataFrame(rows_data)      return sample_data, int_results_df  def main():     # Prompt user to input the parent directory     parent_directory = input("Enter the parent directory path: ")      # Initialize lists to store extracted data     sample_data_list = []     int_results_df_list = []      # Loop through each file in the directory     for filename in os.listdir(parent_directory):         # Check if the file ends with ".xls"         if filename.endswith(".xls"):             file_path = os.path.join(parent_directory, filename)                          # Extract data from specific cells             sample_data, int_results_df = extract_data_from_cells(file_path)                          # Append the extracted data to the respective lists             sample_data_list.append(sample_data)             int_results_df_list.append(int_results_df)      # Convert the extracted data into dataframes     sample_df = pd.DataFrame(sample_data_list)     int_results_df_combined = pd.concat(int_results_df_list)          # Print the extracted dataframes     print("Sample Dataframe:")     print(sample_df)     print("\\nIntResults Dataframe:")     print(int_results_df_combined)          # Save IntResults DataFrame to CSV     int_results_csv_path = os.path.join(parent_directory, "int_results.csv")     int_results_df_combined.to_csv(int_results_csv_path, index=False)     print(f"IntResults DataFrame saved to: {int_results_csv_path}")  if __name__ == "__main__":     main()'

# %%
import os
import xlrd
import pandas as pd

def extract_data_from_cells(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Initialize dictionaries to store extracted data
    sample_data = {}
    int_results_data = {}

    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    sample_data['SampleName'] = sheet1.cell_value(rowx=25, colx=1)  # B26
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Loop through cells for each value starting from row 2 up to row 2 + n
    for row in range(2, 2 + n):
        row_data = {}
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)
        int_results_data[row] = row_data

    return sample_data, int_results_data

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_data_list = []

    # Loop through each file in the directory
    for filename in os.listdir(parent_directory):
        # Check if the file ends with ".xls"
        if filename.endswith(".xls"):
            file_path = os.path.join(parent_directory, filename)
            
            # Extract data from specific cells
            sample_data, int_results_data = extract_data_from_cells(file_path)
            
            # Append the extracted data to the respective lists
            sample_data_list.append(sample_data)
            int_results_data_list.append(int_results_data)

    # Convert the extracted data into dataframes
    sample_df = pd.DataFrame(sample_data_list)
    int_results_df = pd.DataFrame(int_results_data_list)
    
    # Print the extracted dataframes
    print("Sample Dataframe:")
    print(sample_df)
    print("\nIntResults Dataframe:")
    print(int_results_df)
    
    # Save IntResults DataFrame to CSV
    int_results_csv_path = os.path.join(parent_directory, "int_results.csv")
    int_results_df.to_csv(int_results_csv_path, index=False)
    print(f"IntResults DataFrame saved to: {int_results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28\2AJ-1401.D
# WARNING *** file size (36244) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Sample Dataframe:
#   SampleName
# 0     ladder
#
# IntResults Dataframe:
#                                                    2  \
# 0  {'RetTime': 2.962707042694092, 'Area': 455.443...
#
#                                                    3  \
# 0  {'RetTime': 3.230930805206299, 'Area': 264.975...
#
#                                                    4  \
# 0  {'RetTime': 3.722414970397949, 'Area': 1017.26...
#
#                                                    5  \
# 0  {'RetTime': 4.433237552642822, 'Area': 647.048...
#
#                                                    6  \
# 0  {'RetTime': 5.14125919342041, 'Area': 215.2375...
#
#                                                    7  \
# 0  {'RetTime': 5.90235710144043, 'Area': 122.6733...
#
#                                                    8
# 0  {'RetTime': '', 'Area': '', 'Height': '', 'Wid...
# IntResults DataFrame saved to: C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28\2AJ-1401.D\int_results.csv

# %%
import os
import xlrd
import pandas as pd

def extract_data_from_cells(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Initialize dictionaries to store extracted data
    sample_data = {}
    int_results_data = {}

    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    sample_data['SampleName'] = sheet1.cell_value(rowx=25, colx=1)  # B26
    
    # Extract data from IntResults sheet
    int_results_sheet = wb.sheet_by_name('IntResults1')
    
    # Check the value of cell B2
    n = int(int_results_sheet.cell_value(rowx=1, colx=1))  # Assuming B2 contains the value of n
    
    # Loop through cells for each value starting from row 2 up to row 2 + n
    for row in range(2, 2 + n):
        row_data = {}
        for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
            row_data[label] = int_results_sheet.cell_value(rowx=row, colx=col)
        int_results_data[row] = row_data

    return sample_data, int_results_data

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_data_list = []

    # Loop through each file in the directory
    for filename in os.listdir(parent_directory):
        # Check if the file ends with ".xls"
        if filename.endswith(".xls"):
            file_path = os.path.join(parent_directory, filename)
            
            # Extract data from specific cells
            sample_data, int_results_data = extract_data_from_cells(file_path)
            
            # Append the extracted data to the respective lists
            sample_data_list.append(sample_data)
            int_results_data_list.append(int_results_data)

    # Convert the extracted data into dataframes
    sample_df = pd.DataFrame(sample_data_list)
    int_results_df = pd.DataFrame(int_results_data_list)
    
    # Print the extracted dataframes
    print("Sample Dataframe:")
    print(sample_df)
    print("\nIntResults Dataframe:")
    print(int_results_df)

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28\2AJ-1401.D
# WARNING *** file size (36244) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Sample Dataframe:
#   SampleName
# 0     ladder
#
# IntResults Dataframe:
#                                                    2  \
# 0  {'RetTime': 2.962707042694092, 'Area': 455.443...
#
#                                                    3  \
# 0  {'RetTime': 3.230930805206299, 'Area': 264.975...
#
#                                                    4  \
# 0  {'RetTime': 3.722414970397949, 'Area': 1017.26...
#
#                                                    5  \
# 0  {'RetTime': 4.433237552642822, 'Area': 647.048...
#
#                                                    6  \
# 0  {'RetTime': 5.14125919342041, 'Area': 215.2375...
#
#                                                    7  \
# 0  {'RetTime': 5.90235710144043, 'Area': 122.6733...
#
#                                                    8
# 0  {'RetTime': '', 'Area': '', 'Height': '', 'Wid...

# %%
# %who
# Out:
# extract_data_from_cells	 main	 merge_csv_files	 openpyxl	 os	 pd	 xlrd

# %%
# This script works, still gives error:
# WARNING *** file size (31238) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

import os
import xlrd
import pandas as pd

def extract_data_from_cells(file_path):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Initialize dictionaries to store extracted data
    sample_data = {}
    int_results_data = {}

    # Extract data from Sheet1 (SampleName)
    sheet1 = wb.sheet_by_name('Sheet1')
    sample_data['SampleName'] = sheet1.cell_value(rowx=25, colx=1)  # B26
    
    # Extract data from IntResults1 (RetTime, Area, Height, Width, Symmetry, Baseline, TimeStart, LevelStart, BaselineStart, TimeEnd)
    int_results_sheet = wb.sheet_by_name('IntResults1')
    for col, label in zip(range(4, 14), ['RetTime', 'Area', 'Height', 'Width', 'Symmetry', 'Baseline', 'TimeStart', 'LevelStart', 'BaselineStart', 'TimeEnd']):
        int_results_data[label] = int_results_sheet.cell_value(rowx=1, colx=col)  # Row 2, Column E to N

    return sample_data, int_results_data

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize lists to store extracted data
    sample_data_list = []
    int_results_data_list = []

    # Loop through each file in the directory
    for filename in os.listdir(parent_directory):
        # Check if the file ends with ".xls"
        if filename.endswith(".xls"):
            file_path = os.path.join(parent_directory, filename)
            
            # Extract data from specific cells
            sample_data, int_results_data = extract_data_from_cells(file_path)
            
            # Append the extracted data to the respective lists
            sample_data_list.append(sample_data)
            int_results_data_list.append(int_results_data)

    # Convert the extracted data into dataframes
    sample_df = pd.DataFrame(sample_data_list)
    int_results_df = pd.DataFrame(int_results_data_list)
    
    # Print the extracted dataframes
    print("Sample Dataframe:")
    print(sample_df)
    print("\nIntResults Dataframe:")
    print(int_results_df)

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 18 770 771 772 773 ELUTIONS 2024-04-18 14-01-28\2AJ-1401.D
# WARNING *** file size (36244) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Sample Dataframe:
#   SampleName
# 0     ladder
#
# IntResults Dataframe:
#     RetTime        Area    Height     Width  Symmetry  Baseline  TimeStart  \
# 0  2.629555  106.284401  6.798275  0.228397  1.765334 -2.602099      2.212
#
#    LevelStart  BaselineStart   TimeEnd
# 0         0.0       0.011444  2.730381

# %%
def extract_data_from_cells(file_path, cell_coordinates):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Select the worksheet named 'Sheet1'
    sheet = wb.sheet_by_name('Sheet1')
    
    # Initialize a dictionary to store extracted data
    extracted_data = {}

    for cell_coord in cell_coordinates:
        # Extract row and column indices from the cell coordinates
        column, row = xlrd.sheet.split_cell(cell_coord)
        
        # Get the value of the cell
        value = sheet.cell_value(rowx=row-1, colx=column-1)
        
        # Store the value in the dictionary
        extracted_data[cell_coord] = value

    return extracted_data

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize an empty dataframe to store extracted data
    extracted_df = pd.DataFrame()

    # Loop through each file in the directory
    for filename in os.listdir(parent_directory):
        # Check if the file ends with ".xls"
        if filename.endswith(".xls"):
            file_path = os.path.join(parent_directory, filename)
            
            # Cell coordinates from which you want to extract data
            cell_coordinates = ["A1", "B2", "C3"]  # Example cell coordinates
            
            # Extract data from specific cells
            extracted_data = extract_data_from_cells(file_path, cell_coordinates)
            
            # Convert the extracted data into a dataframe
            df = pd.DataFrame(extracted_data, index=[0])
            
            # Append the dataframe to the extracted_df
            extracted_df = pd.concat([extracted_df, df], ignore_index=True)

    # Print the extracted dataframe
    print("Extracted Dataframe:")
    print(extracted_df)

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 26 769-773 ELUTIONS POOL PBS 2024-04-26 14-57-25\2BB-0501.D
# WARNING *** file size (31238) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 53
#      50     print(extracted_df)
#      52 if __name__ == "__main__":
# ---> 53     main()
#
# Cell In[4], line 40, in main()
#      37 cell_coordinates = ["A1", "B2", "C3"]  # Example cell coordinates
#      39 # Extract data from specific cells
# ---> 40 extracted_data = extract_data_from_cells(file_path, cell_coordinates)
#      42 # Convert the extracted data into a dataframe
#      43 df = pd.DataFrame(extracted_data, index=[0])
#
# Cell In[4], line 13, in extract_data_from_cells(file_path, cell_coordinates)
#       9 extracted_data = {}
#      11 for cell_coord in cell_coordinates:
#      12     # Extract row and column indices from the cell coordinates
# ---> 13     column, row = xlrd.sheet.split_cell(cell_coord)
#      15     # Get the value of the cell
#      16     value = sheet.cell_value(rowx=row-1, colx=column-1)
#
# AttributeError: module 'xlrd.sheet' has no attribute 'split_cell'

# %%
import os
import xlrd
import pandas as pd

def extract_data_from_cells(file_path, cell_coordinates):
    # Open the Excel file
    wb = xlrd.open_workbook(file_path)
    
    # Select the worksheet named 'Sheet1'
    sheet = wb.sheet_by_name('Sheet1')
    
    # Initialize a dictionary to store extracted data
    extracted_data = {}

    for cell_coord in cell_coordinates:
        # Extract row and column indices from the cell coordinates
        column, row = xlrd.cellname.split(cell_coord)
        
        # Get the value of the cell
        value = sheet.cell_value(rowx=int(row)-1, colx=int(column)-1)
        
        # Store the value in the dictionary
        extracted_data[cell_coord] = value

    return extracted_data

def main():
    # Prompt user to input the parent directory
    parent_directory = input("Enter the parent directory path: ")

    # Initialize an empty dataframe to store extracted data
    extracted_df = pd.DataFrame()

    # Loop through each file in the directory
    for filename in os.listdir(parent_directory):
        # Check if the file ends with ".xls"
        if filename.endswith(".xls"):
            file_path = os.path.join(parent_directory, filename)
            
            # Cell coordinates from which you want to extract data
            cell_coordinates = ["A1", "B2", "C3"]  # Example cell coordinates
            
            # Extract data from specific cells
            extracted_data = extract_data_from_cells(file_path, cell_coordinates)
            
            # Convert the extracted data into a dataframe
            df = pd.DataFrame(extracted_data, index=[0])
            
            # Append the dataframe to the extracted_df
            extracted_df = pd.concat([extracted_df, df], ignore_index=True)

    # Print the extracted dataframe
    print("Extracted Dataframe:")
    print(extracted_df)

if __name__ == "__main__":
    main()
# Out:
# Enter the parent directory path:  C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 04 26 769-773 ELUTIONS POOL PBS 2024-04-26 14-57-25\2BB-0501.D
# WARNING *** file size (31238) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 57
#      54     print(extracted_df)
#      56 if __name__ == "__main__":
# ---> 57     main()
#
# Cell In[5], line 44, in main()
#      41 cell_coordinates = ["A1", "B2", "C3"]  # Example cell coordinates
#      43 # Extract data from specific cells
# ---> 44 extracted_data = extract_data_from_cells(file_path, cell_coordinates)
#      46 # Convert the extracted data into a dataframe
#      47 df = pd.DataFrame(extracted_data, index=[0])
#
# Cell In[5], line 17, in extract_data_from_cells(file_path, cell_coordinates)
#      13 extracted_data = {}
#      15 for cell_coord in cell_coordinates:
#      16     # Extract row and column indices from the cell coordinates
# ---> 17     column, row = xlrd.cellname.split(cell_coord)
#      19     # Get the value of the cell
#      20     value = sheet.cell_value(rowx=int(row)-1, colx=int(column)-1)
#
# AttributeError: 'function' object has no attribute 'split'

# %%
def merge_csv_files(parent_folder):
    # Initialize an empty dataframe
    merged_df = pd.DataFrame()

    # Loop through each folder in the parent folder
    for folder_name in os.listdir(parent_folder):
        folder_path = os.path.join(parent_folder, folder_name)
        
        # Check if the current item is a directory
        if os.path.isdir(folder_path):
            # Loop through each file in the directory
            for file_name in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file_name)
                
                # Check if the file is a CSV file
                if file_name.endswith('01.CSV'):
                    # Read the CSV file into a dataframe
                    df = pd.read_csv(file_path, encoding='iso-8859-1')
                    
                    # Append the dataframe to the merged dataframe
                    merged_df = merged_df.append(df, ignore_index=True)

    return merged_df

def main():
    # Specify the parent folder containing subfolders with CSV files
    #parent_folder = "10.2.20.249/Lab Data/Joel Tencer/Agilent HPLC 1/HIC\WX71117_2 2024-04-01 10-57-02"
    parent_folder = "C:/Users/JoelTencer/Documents/HPLC/HIC/WX71117_2 2024-04-01 10-57-02"
    
    # Merge CSV files from subfolders into a single dataframe
    merged_df = merge_csv_files(parent_folder)
    
    # Export the merged dataframe as a single CSV file
    merged_df.to_csv("merged_data.csv", index=False)
    print("Merged data exported successfully.")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13280\2766758274.py in ?()
#      34     merged_df.to_csv("merged_data.csv", index=False)
#      35     print("Merged data exported successfully.")
#      36
#      37 if __name__ == "__main__":
# ---> 38     main()
#
# ~\AppData\Local\Temp\ipykernel_13280\2766758274.py in ?()
#      27     #parent_folder = "10.2.20.249/Lab Data/Joel Tencer/Agilent HPLC 1/HIC\WX71117_2 2024-04-01 10-57-02"
#      28     parent_folder = "C:/Users/JoelTencer/Documents/HPLC/HIC/WX71117_2 2024-04-01 10-57-02"
#      29
#      30     # Merge CSV files from subfolders into a single dataframe
# ---> 31     merged_df = merge_csv_files(parent_folder)
#      32
#      33     # Export the merged dataframe as a single CSV file
#      34     merged_df.to_csv("merged_data.csv", index=False)
#
# ~\AppData\Local\Temp\ipykernel_13280\2766758274.py in ?(parent_folder)
#      17                     # Read the CSV file into a dataframe
#      18                     df = pd.read_csv(file_path, encoding='iso-8859-1')
#      19
#      20                     # Append the dataframe to the merged dataframe
# ---> 21                     merged_df = merged_df.append(df, ignore_index=True)
#      22
#      23     return merged_df
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
def extract_data_from_cells(file_path, cell_coordinates):
    # Load the Excel file
    wb = openpyxl.load_workbook(file_path)
    
    # Select the worksheet named 'Sheet1'
    sheet = wb['Sheet1']
    
    # Initialize a dictionary to store extracted data
    extracted_data = {}

    for cell_coord in cell_coordinates:
        # Extract row and column indices from the cell coordinates
        column, row = openpyxl.utils.cell.coordinate_from_string(cell_coord)
        
        # Get the value of the cell
        value = sheet.cell(row=row, column=column).value
        
        # Store the value in the dictionary
        extracted_data[cell_coord] = value

    return extracted_data

def main():
    # File path
    file_path = "example.xlsx"  # Replace with your Excel file path
    
    # Cell coordinates from which you want to extract data
    cell_coordinates = ["A1", "B2", "C3"]  # Example cell coordinates
    
    # Extract data from specific cells
    extracted_data = extract_data_from_cells(file_path, cell_coordinates)
    
    # Print the extracted data
    for cell_coord, value in extracted_data.items():
        print(f"Data extracted from cell {cell_coord}: {value}")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 38
#      35         print(f"Data extracted from cell {cell_coord}: {value}")
#      37 if __name__ == "__main__":
# ---> 38     main()
#
# Cell In[8], line 31, in main()
#      28 cell_coordinates = ["A1", "B2", "C3"]  # Example cell coordinates
#      30 # Extract data from specific cells
# ---> 31 extracted_data = extract_data_from_cells(file_path, cell_coordinates)
#      33 # Print the extracted data
#      34 for cell_coord, value in extracted_data.items():
#
# Cell In[8], line 3, in extract_data_from_cells(file_path, cell_coordinates)
#       1 def extract_data_from_cells(file_path, cell_coordinates):
#       2     # Load the Excel file
# ----> 3     wb = openpyxl.load_workbook(file_path)
#       5     # Select the worksheet named 'Sheet1'
#       6     sheet = wb['Sheet1']
#
# File ~\anaconda3\Lib\site-packages\openpyxl\reader\excel.py:315, in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     288 def load_workbook(filename, read_only=False, keep_vba=KEEP_VBA,
#     289                   data_only=False, keep_links=True):
#     290     """Open the given filename and return the workbook
#     291
#     292     :param filename: the path to open or a file-like object
#    (...)
#     313
#     314     """
# --> 315     reader = ExcelReader(filename, read_only, keep_vba,
#     316                         data_only, keep_links)
#     317     reader.read()
#     318     return reader.wb
#
# File ~\anaconda3\Lib\site-packages\openpyxl\reader\excel.py:124, in ExcelReader.__init__(self, fn, read_only, keep_vba, data_only, keep_links)
#     122 def __init__(self,  fn, read_only=False, keep_vba=KEEP_VBA,
#     123               data_only=False, keep_links=True):
# --> 124     self.archive = _validate_archive(fn)
#     125     self.valid_files = self.archive.namelist()
#     126     self.read_only = read_only
#
# File ~\anaconda3\Lib\site-packages\openpyxl\reader\excel.py:96, in _validate_archive(filename)
#      89             msg = ('openpyxl does not support %s file format, '
#      90                    'please check you can open '
#      91                    'it with Excel first. '
#      92                    'Supported formats are: %s') % (file_format,
#      93                                                    ','.join(SUPPORTED_FORMATS))
#      94         raise InvalidFileException(msg)
# ---> 96 archive = ZipFile(filename, 'r')
#      97 return archive
#
# File ~\anaconda3\Lib\zipfile.py:1284, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1282 while True:
#    1283     try:
# -> 1284         self.fp = io.open(file, filemode)
#    1285     except OSError:
#    1286         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example.xlsx'
